# %% [markdown]
# # Show all of GPy's kernels

# %% [markdown]
# adapted from https://gist.github.com/rikrd/05f5ca0c31adb9203823#file-gpy_kernel_cheatsheet-py

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import numpy as np
import pylab as plt
import GPy
import re


def get_equation(kern):
    match = re.search(
        r"(math::)(\r\n|\r|\n)*(?P<equation>.*)(\r\n|\r|\n)*", kern.__doc__
    )
    return "" if match is None else match.group("equation").strip()


for kernel_name in dir(GPy.kern):
    Kernel = getattr(GPy.kern, kernel_name)

    if (
        Kernel.__class__
        == GPy.kern.Exponential.__class__
        == GPy.kern.src.kernel_slice_operations.KernCallsViaSlicerMeta
    ):
        # Try plotting sample paths here
        try:
            k = Kernel(input_dim=1)

            X = np.linspace(
                0.0, 1.0, 500
            )  # define X to be 500 points evenly spaced over [0,1]
            X = X[
                :, None
            ]  # reshape X to make it n*p --- we try to use 'design matrices' in GPy

            mu = np.zeros(
                (500)
            )  # vector of the means --- we could use a mean function here, but here it is just zero.
            C = k.K(X, X)  # compute the covariance matrix associated with inputs X

            # Generate 20 separate samples paths from a Gaussian with mean mu and covariance C
            Z = np.random.multivariate_normal(mu, C, 20)

            kernel_equation = get_equation(k)
            # print kernel_equation
            from IPython.display import Math, display

            display(Math(kernel_equation))

            fig = plt.figure()  # open a new plotting window
            plt.subplot(121)
            for i in range(3):
                plt.plot(X[:], Z[i, :])

            plt.title("{} samples".format(kernel_name))

            plt.subplot(122)
            plt.imshow(C, interpolation="nearest")
            plt.title("{} covariance".format(kernel_name))
        except:
            continue
# Out:
# $\displaystyle $
# $\displaystyle $
# $\displaystyle r(x, x') = \sqrt{ \sum_{q=1}^Q (x_q - x'_q)^2 }$
# $\displaystyle k(r) = \sigma^2 (1 + \sqrt{5} r + \frac53 r^2) \exp(- \sqrt{5} r)$
# $\displaystyle r(x, x') = \sqrt{ \sum_{q=1}^Q (x_q - x'_q)^2 }$
# $\displaystyle k(r) = \sigma^2 \exp \bigg(- \frac{1}{2} r^2 \bigg)$
#  /Users/andy/Library/Python/3.6/lib/python/site-packages/paramz/transformations.py:115: RuntimeWarning:invalid value encountered in less
# $\displaystyle k(x,y) = \sum_{i=1}^{\text{input_dim}} \sigma^2_i x_iy_i$
# $\displaystyle k(x,y) = \sigma^{2}\frac{2}{\pi }  \text{asin} \left ( \frac{ \sigma_w^2 x^\top y+\sigma_b^2}{\sqrt{\sigma_w^2x^\top x + \sigma_b^2 + 1}\sqrt{\sigma_w^2 y^\top y + \sigma_b^2 +1}} \right )$
# $\displaystyle k(r) = \sigma^2 (1 + \sqrt{3} r) \exp(- \sqrt{3} r) \ \ \ \  \text{ where  } r = \sqrt{\sum_{i=1}^{\text{input_dim}} \frac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(r) = \sigma^2 (1 + \sqrt{5} r + \frac53 r^2) \exp(- \sqrt{5} r)$
# $\displaystyle k(r) = \sigma^2 \exp(- r) \ \ \ \  \text{ where  } r = \sqrt{\sum_{i=1}^{	ext{input_dim}} \frac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle $
# $\displaystyle $
# $\displaystyle $
# $\displaystyle $
# $\displaystyle k(r) = \sigma^2 \exp \bigg(- \frac{1}{2} r^2 \bigg)$
# $\displaystyle k(r) = \sigma^2 \bigg( 1 + \frac{r^2}{2} \bigg)^{- \alpha}$
# $\displaystyle $
# $\displaystyle k(x,y) = 	heta_1 \exp \left[  - rac{1}{2} \sum_{i=1}^{input\_dim}$
# $\displaystyle $
# $\displaystyle k(x,y) = lpha$
#  /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:47: RuntimeWarning:More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# $\displaystyle k(x,y) = \sigma^2 min(x,y)$
# $\displaystyle k(r) = \sigma^2 \exp \bigg(- \frac{1}{2} r \bigg) \ \ \ \  	ext{ where  } r = \sqrt{\sum_{i=1}^{input dim} rac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(r) = \sigma^2 (1 + \sqrt{3} r) \exp(- \sqrt{3} r) \ \ \ \  	ext{ where  } r = \sqrt{\sum_{i=1}^{input dim} rac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(r) = \sigma^2 (1 + \sqrt{5} r + rac{5}{3}r^2) \exp(- \sqrt{5} r) \ \ \ \  	ext{ where  } r = \sqrt{\sum_{i=1}^{input dim} rac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(r) = \sigma^2 \exp \bigg(- \frac{1}{2} r^2 \bigg) \ \ \ \  	ext{ where  } r = \sqrt{\sum_{i=1}^{input dim} rac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(r) = \sigma^2 \bigg( 1 + \frac{r^2}{2} \bigg)^{- lpha} \ \ \ \  	ext{ where  } r = \sqrt{\sum_{i=1}^{input dim} rac{(x_i-y_i)^2}{\ell_i^2} }$
# $\displaystyle k(x,y) = 	heta_1 \exp \left[  - rac{1}{2} {}\sum_{i=1}^{input\_dim}$
# $\displaystyle k(x,y) = lpha*\delta(x-y)$
