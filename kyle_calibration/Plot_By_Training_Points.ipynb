# %%
#!/bin/env python3

from argparse import ArgumentParser
from ast import Str

import numpy as np
from math import comb
import os
from os.path import join

from pathlib import Path

import pandas as pd
import pylab as plt
import random
import time
import warnings

from matplotlib.ticker import NullFormatter
from matplotlib.patches import Polygon
from matplotlib.lines import Line2D


# wrapper for pylab, designed to do statistical plots using pandas dataframe 

from scipy.stats import beta, gaussian_kde


import sys
sys.path.append('/home/kblum/local/pism/sources/pism-emulator/')

from pismemulator.utils import param_keys_dict as keys_dict
from pismemulator.utils import kl_divergence

import seaborn as sns

# %%
def plot_multiple_groups(dfs,vars,data_group_things):
    # df : data frame of all models for true avg
    # vars: list of variable (column) names
    # models: list of available models (0,1,2 ...)
    # num_groups: number of ensembles
    # per_group: number of emulators per ensemble

    sns.set_theme(palette='colorblind')
    rows = int(np.ceil(len(vars)/2))
    cols = 2

    fig, axes = plt.subplots(rows,cols,figsize=(11.69,17.44))

    groups = []
    
    foo = 0
    bar = 0
    for i in range(rows):
        for j in range (cols):            
            var = vars[foo]
            print(var)
            for count, df in enumerate(dfs):
                sns.kdeplot(data=df,x=var,ax=axes[int(i),int(j)],label=data_group_things[count]) # remove y axis values, add x axis label
                axes[i,j].set(xlabel=keys_dict[var],yticklabels=[],ylabel=None)
            axes[int(i),int(j)].legend()
            foo += 1

def kl_divergences(df,vars,models,num_groups=10,per_group=60):
    # df : data frame of all models for true avg
    # vars: list of variable (column) names
    # models: list of available models (0,1,2 ...)
    # num_groups: number of ensembles
    # per_group: number of emulators per ensemble

    divs = {}
    groups = []

    random.seed(8675309)
    for i in range(num_groups):
        groups.append(random.sample(sorted(models),per_group))
    
    bar = 0
    for i in range(len(vars)):
        kl_average = 0
        var = vars[i]
        p = np.histogram(df[var], bins=30,density=True)[0]
        for group in groups:
            temp = df[df['Model'].isin(group)]
            q = np.histogram(temp[var],bins=30,density=True)[0]
            kl_average += np.abs(kl_divergence(p,q))
        kl_average  = kl_average / num_groups
        divs[var] = kl_average
    return divs

# %%
emulator_dirs = []
clever_var_name = [250,500,750,1000]
for i in clever_var_name:
    emulator_dir = f"/data/work/antarctica_calibration/speedemulator/pp_50m_{i}t_1000e"
    emulator_dirs.append(emulator_dir)
samples_file = "/data/work/antarctica_calibration/speed_calibration_pseudo_plastic_128.csv"
frac         = 0.1

print("Loading prior samples\n")
samples = pd.read_csv(samples_file).drop(columns=["id"])

X = samples.values
X_mean = samples.mean(axis=0)
X_std = samples.std(axis=0)
X_keys = samples.keys()

n_samples, n_parameters = X.shape

X_min = (((X.min(axis=0) - X_mean) / X_std - 1e-3) * X_std + X_mean).values
X_max = (((X.max(axis=0) - X_mean) / X_std + 1e-3) * X_std + X_mean).values

# We assume a beta(3,3) distr as our prior
alpha_b = 3.0
beta_b = 3.0
X_prior = (
    beta.rvs(alpha_b, beta_b, size=(100000, n_parameters)) * (X_max - X_min) + X_min
)

l_post = []
# Out:
# Loading prior samples

# %%
posterior_dfs = []
models_list = []
for emulator_dir in emulator_dirs:
        
    X_list = []
    
    p = Path(f"{emulator_dir}/posterior_samples/")
    print("Loading posterior samples\n")
    for m, m_file in enumerate(sorted(p.glob("X_posterior_model_*.csv.gz"))):
        #print(f"  -- {m_file}")
        df = pd.read_csv(m_file).sample(frac=1)
        if "Unnamed: 0" in df.columns:
            df.drop(columns=["Unnamed: 0"], inplace=True)
        model = m_file.name.split("_")[-1].split(".")[0]
        df["Model"] = int(model)
        X_list.append(df)

    training = emulator_dir.split("_")[3].split("t")[0]
    print(f"Merging posteriors into dataframe")

    posterior_df = pd.concat(X_list)
    posterior_df["Training"] = int(training)
    
    print(training)
    posterior_dfs.append(posterior_df)
    #X_posterior = posterior_df.drop(columns=["Model"]).values
    models = posterior_df['Model'].unique()
    models_list.append(models)
# Out:
# Loading posterior samples
#
# Merging posteriors into dataframe
# 250
# Loading posterior samples
#
# Merging posteriors into dataframe
# 500
# Loading posterior samples
#
# Merging posteriors into dataframe
# 750
# Loading posterior samples
#
# Merging posteriors into dataframe
# 1000

# %%
aggr_samples_250  = posterior_dfs[0]
aggr_samples_500  = posterior_dfs[1]
aggr_samples_750  = posterior_dfs[2]
aggr_samples_1000 = posterior_dfs[3]

# %%
aggr_samples_250.to_parquet()

# %%
aggr_samples_500.to_parquet()

# %%
aggr_samples_750.to_parquet()

# %%
aggr_samples_1000.to_parquet()

# %%
plot_multiple_groups(posterior_dfs, X_keys, clever_var_name)
#sns.kdeplot(data=posterior_dfs, x=var,ax=axes[i,j],color='black')
# Out:
# sia_e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 plot_multiple_groups(posterior_dfs, X_keys, clever_var_name)
#
# Cell In [8], line 23, in plot_multiple_groups(dfs, vars, data_group_things)
#      21 print(var)
#      22 for count, df in enumerate(dfs):
# ---> 23     sns.kdeplot(data=df,x=var,ax=axes[int(i),int(j)],label=data_group_things[count]) # remove y axis values, add x axis label
#      24     axes[i,j].set(xlabel=keys_dict[var],yticklabels=[],ylabel=None)
#      25 axes[int(i),int(j)].legend()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:1723, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1719 if p.univariate:
#    1721     plot_kws = kwargs.copy()
# -> 1723     p.plot_univariate_density(
#    1724         multiple=multiple,
#    1725         common_norm=common_norm,
#    1726         common_grid=common_grid,
#    1727         fill=fill,
#    1728         color=color,
#    1729         legend=legend,
#    1730         warn_singular=warn_singular,
#    1731         estimate_kws=estimate_kws,
#    1732         **plot_kws,
#    1733     )
#    1735 else:
#    1737     p.plot_bivariate_density(
#    1738         common_norm=common_norm,
#    1739         fill=fill,
#    (...)
#    1749         **kwargs,
#    1750     )
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:935, in _DistributionPlotter.plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, color, legend, estimate_kws, **plot_kws)
#     932 log_scale = self._log_scaled(self.data_variable)
#     934 # Do the computation
# --> 935 densities = self._compute_univariate_density(
#     936     self.data_variable,
#     937     common_norm,
#     938     common_grid,
#     939     estimate_kws,
#     940     log_scale,
#     941     warn_singular,
#     942 )
#     944 # Adjust densities based on the `multiple` rule
#     945 densities, baselines = self._resolve_multiple(densities, multiple)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:352, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     348 try:
#     349     if not singular:
#     350         # Convoluted approach needed because numerical failures
#     351         # can manifest in a few different ways.
# --> 352         density, support = estimator(observations, weights=weights)
#     353 except np.linalg.LinAlgError:
#     354     singular = True
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_statistics.py:192, in KDE.__call__(self, x1, x2, weights)
#     190 """Fit and evaluate on univariate or bivariate data."""
#     191 if x2 is None:
# --> 192     return self._eval_univariate(x1, weights)
#     193 else:
#     194     return self._eval_bivariate(x1, x2, weights)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_statistics.py:161, in KDE._eval_univariate(self, x, weights)
#     157     density = np.array([
#     158         kde.integrate_box_1d(s_0, s_i) for s_i in support
#     159     ])
#     160 else:
# --> 161     density = kde(support)
#     163 return density, support
#
# File /usr/lib/python3/dist-packages/scipy/stats/_kde.py:253, in gaussian_kde.evaluate(self, points)
#     250 else:
#     251     raise TypeError('%s has unexpected item size %d' %
#     252                     (output_dtype, itemsize))
# --> 253 result = gaussian_kernel_estimate[spec](self.dataset.T, self.weights[:, None],
#     254                                         points.T, self.inv_cov, output_dtype)
#     255 return result[:, 0]
#
# KeyboardInterrupt:

# %%
np.seterr(invalid='ignore',divide='ignore')
lcurves = {}
xs = np.linspace(5,200,40)
for per_group in xs:
    print(per_group)
    lcurves[per_group] = kl_divergences(posterior_df, X_keys, models, per_group=int(per_group),num_groups=20)
# Out:
# 5.0
# 10.0
# 15.0
# 20.0
# 25.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 6
#       4 for per_group in xs:
#       5     print(per_group)
# ----> 6     lcurves[per_group] = kl_divergences(posterior_df, X_keys, models, per_group=int(per_group),num_groups=20)
#
# Cell In [2], line 48, in kl_divergences(df, vars, models, num_groups, per_group)
#      46 p = np.histogram(df[var], bins=30,density=True)[0]
#      47 for group in groups:
# ---> 48     temp = df[df['Model'].isin(group)]
#      49     q = np.histogram(temp[var],bins=30,density=True)[0]
#      50     kl_average += np.abs(kl_divergence(p,q))
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3449, in DataFrame.__getitem__(self, key)
#    3447 # Do we have a (boolean) 1d indexer?
#    3448 if com.is_bool_indexer(key):
# -> 3449     return self._getitem_bool_array(key)
#    3451 # We are left with two options: a single key, and a collection of keys,
#    3452 # We interpret tuples as collections only for non-MultiIndex
#    3453 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3503, in DataFrame._getitem_bool_array(self, key)
#    3500 # check_bool_indexer will throw exception if Series key cannot
#    3501 # be reindexed to match DataFrame rows
#    3502 key = check_bool_indexer(self.index, key)
# -> 3503 indexer = key.nonzero()[0]
#    3504 return self._take_with_is_copy(indexer, axis=0)
#
# KeyboardInterrupt:

# %%
rows = int(np.ceil(len(X_keys)/2))
cols = 2

fig, axes = plt.subplots(rows,cols,figsize=(11.69,17.44))
foo = 0

for i in range(rows):
    for j in range (cols):
        var = X_keys[foo]
        foo += 1
        ys = []
        for bar in xs:
            ys.append(lcurves[bar][var])
        
        axes[i,j].plot(xs,ys,'k.-')
        axes[i,j].set(xlabel=keys_dict[var],yticklabels=[],ylabel=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 12
#      10 foo += 1
#      11 ys = []
# ---> 12 for bar in xs:
#      13     ys.append(lcurves[bar][var])
#      15 axes[i,j].plot(xs,ys,'k.-')
#
# NameError: name 'xs' is not defined

# %%
#print(plot_groups(posterior_df, X_keys, models, per_group=15))
for pergroup in [15,50,100]:
    print(kl_divergences(posterior_df, X_keys, models, per_group=int(pergroup),num_groups=20)['ppq'])
