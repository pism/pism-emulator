# %%
#!/bin/env python3

from argparse import ArgumentParser
from ast import Str

import numpy as np
from math import comb
import os
from os.path import join

from pathlib import Path

import pandas as pd
import pylab as plt
import random
import time
import warnings

from matplotlib.ticker import NullFormatter
from matplotlib.patches import Polygon
from matplotlib.lines import Line2D


# wrapper for pylab, designed to do statistical plots using pandas dataframe 

from scipy.stats import beta, gaussian_kde


import sys
sys.path.append('/home/kblum/local/pism/sources/pism-emulator/')

from pismemulator.utils import param_keys_dict as keys_dict
from pismemulator.utils import kl_divergence

import seaborn as sns

# %%
def plot_multiple_groups(dfs,vars,data_group_things):
    # df : data frame of all models for true avg
    # vars: list of variable (column) names
    # models: list of available models (0,1,2 ...)
    # num_groups: number of ensembles
    # per_group: number of emulators per ensemble

    sns.set_theme(palette='colorblind')
    rows = int(np.ceil(len(vars)/2))
    cols = 2

    fig, axes = plt.subplots(rows,cols,figsize=(11.69,17.44))

    groups = []
    
    foo = 0
    bar = 0
    for i in range(rows):
        for j in range (cols):            
            var = vars[foo]
            print(var)
            for count, df in enumerate(dfs):
                sns.kdeplot(data=df,x=var,ax=axes[int(i),int(j)],label=data_group_things[count]) # remove y axis values, add x axis label
                axes[i,j].set(xlabel=keys_dict[var],yticklabels=[],ylabel=None)
            axes[int(i),int(j)].legend()
            foo += 1

def kl_divergences(df,vars,models,num_groups=10,per_group=60):
    # df : data frame of all models for true avg
    # vars: list of variable (column) names
    # models: list of available models (0,1,2 ...)
    # num_groups: number of ensembles
    # per_group: number of emulators per ensemble

    divs = {}
    groups = []

    random.seed(8675309)
    for i in range(num_groups):
        groups.append(random.sample(sorted(models),per_group))
    
    bar = 0
    for i in range(len(vars)):
        kl_average = 0
        var = vars[i]
        p = np.histogram(df[var], bins=30,density=True)[0]
        for group in groups:
            temp = df[df['Model'].isin(group)]
            q = np.histogram(temp[var],bins=30,density=True)[0]
            kl_average += np.abs(kl_divergence(p,q))
        kl_average  = kl_average / num_groups
        divs[var] = kl_average
    return divs

# %%
emulator_dirs = []
clever_var_name = [250,500,750,1000]
for i in clever_var_name:
    emulator_dir = f"/data/work/antarctica_calibration/speedemulator/pp_50m_{i}t_1000e"
    emulator_dirs.append(emulator_dir)
samples_file = "/data/work/antarctica_calibration/speed_calibration_pseudo_plastic_128.csv"
frac         = 0.1

print("Loading prior samples\n")
samples = pd.read_csv(samples_file).drop(columns=["id"])

X = samples.values
X_mean = samples.mean(axis=0)
X_std = samples.std(axis=0)
X_keys = samples.keys()

n_samples, n_parameters = X.shape

X_min = (((X.min(axis=0) - X_mean) / X_std - 1e-3) * X_std + X_mean).values
X_max = (((X.max(axis=0) - X_mean) / X_std + 1e-3) * X_std + X_mean).values

# We assume a beta(3,3) distr as our prior
alpha_b = 3.0
beta_b = 3.0
X_prior = (
    beta.rvs(alpha_b, beta_b, size=(100000, n_parameters)) * (X_max - X_min) + X_min
)

l_post = []
# Out:
# Loading prior samples

# %%
posterior_dfs = []
models_list = []
for emulator_dir in emulator_dirs:
        
    X_list = []
    p = Path(f"{emulator_dir}/posterior_samples/")
    print("Loading posterior samples\n")
    for m, m_file in enumerate(sorted(p.glob("X_posterior_model_*.csv.gz"))):
        #print(f"  -- {m_file}")
        df = pd.read_csv(m_file).sample(frac=frac)
        if "Unnamed: 0" in df.columns:
            df.drop(columns=["Unnamed: 0"], inplace=True)
        model = m_file.name.split("_")[-1].split(".")[0]
        df["Model"] = int(model)
        X_list.append(df)

    print(f"Merging posteriors into dataframe")
    posterior_df = pd.concat(X_list)
    posterior_dfs.append(posterior_df)
    #X_posterior = posterior_df.drop(columns=["Model"]).values
    models = posterior_df['Model'].unique()
    models_list.append(models)
# Out:
# Loading posterior samples
#
# Merging posteriors into dataframe
# Loading posterior samples
#
# Merging posteriors into dataframe
# Loading posterior samples
#
# Merging posteriors into dataframe
# Loading posterior samples
#
# Merging posteriors into dataframe

# %%
plot_multiple_groups(posterior_dfs, X_keys, clever_var_name)
#sns.kdeplot(data=posterior_dfs, x=var,ax=axes[i,j],color='black')
# Out:
# sia_e
# ssa_e
# ppq
# tefo
# phi_min
# z_min
# z_max
# pseudo_plastic_uthreshold

# %%
np.seterr(invalid='ignore',divide='ignore')
lcurves = {}
xs = np.linspace(5,200,40)
for per_group in xs:
    print(per_group)
    lcurves[per_group] = kl_divergences(posterior_df, X_keys, models, per_group=int(per_group),num_groups=20)
# Out:
# 5.0
# 10.0
# 15.0
# 20.0
# 25.0
# 30.0
# 35.0
# 40.0
# 45.0
# 50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [28], line 6
#       4 for per_group in xs:
#       5     print(per_group)
# ----> 6     lcurves[per_group] = kl_divergences(posterior_df, X_keys, models, per_group=int(per_group),num_groups=20)
#
# Cell In [27], line 48, in kl_divergences(df, vars, models, num_groups, per_group)
#      46 p = np.histogram(df[var], bins=30,density=True)[0]
#      47 for group in groups:
# ---> 48     temp = df[df['Model'].isin(group)]
#      49     q = np.histogram(temp[var],bins=30,density=True)[0]
#      50     kl_average += np.abs(kl_divergence(p,q))
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3449, in DataFrame.__getitem__(self, key)
#    3447 # Do we have a (boolean) 1d indexer?
#    3448 if com.is_bool_indexer(key):
# -> 3449     return self._getitem_bool_array(key)
#    3451 # We are left with two options: a single key, and a collection of keys,
#    3452 # We interpret tuples as collections only for non-MultiIndex
#    3453 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3504, in DataFrame._getitem_bool_array(self, key)
#    3502 key = check_bool_indexer(self.index, key)
#    3503 indexer = key.nonzero()[0]
# -> 3504 return self._take_with_is_copy(indexer, axis=0)
#
# File /usr/lib/python3/dist-packages/pandas/core/generic.py:3628, in NDFrame._take_with_is_copy(self, indices, axis)
#    3620 def _take_with_is_copy(self: FrameOrSeries, indices, axis=0) -> FrameOrSeries:
#    3621     """
#    3622     Internal version of the `take` method that sets the `_is_copy`
#    3623     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3626     See the docstring of `take` for full explanation of the parameters.
#    3627     """
# -> 3628     result = self.take(indices=indices, axis=axis)
#    3629     # Maybe set copy if we didn't actually change the index.
#    3630     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File /usr/lib/python3/dist-packages/pandas/core/generic.py:3615, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3611 nv.validate_take((), kwargs)
#    3613 self._consolidate_inplace()
# -> 3615 new_data = self._mgr.take(
#    3616     indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617 )
#    3618 return self._constructor(new_data).__finalize__(self, method="take")
#
# File /usr/lib/python3/dist-packages/pandas/core/internals/managers.py:865, in BaseBlockManager.take(self, indexer, axis, verify)
#     862 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     864 new_labels = self.axes[axis].take(indexer)
# --> 865 return self.reindex_indexer(
#     866     new_axis=new_labels,
#     867     indexer=indexer,
#     868     axis=axis,
#     869     allow_dups=True,
#     870     consolidate=False,
#     871 )
#
# File /usr/lib/python3/dist-packages/pandas/core/internals/managers.py:680, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     676     new_blocks = self._slice_take_blocks_ax0(
#     677         indexer, fill_value=fill_value, only_slice=only_slice
#     678     )
#     679 else:
# --> 680     new_blocks = [
#     681         blk.take_nd(
#     682             indexer,
#     683             axis=1,
#     684             fill_value=(
#     685                 fill_value if fill_value is not None else blk.fill_value
#     686             ),
#     687         )
#     688         for blk in self.blocks
#     689     ]
#     691 new_axes = list(self.axes)
#     692 new_axes[axis] = new_axis
#
# File /usr/lib/python3/dist-packages/pandas/core/internals/managers.py:681, in <listcomp>(.0)
#     676     new_blocks = self._slice_take_blocks_ax0(
#     677         indexer, fill_value=fill_value, only_slice=only_slice
#     678     )
#     679 else:
#     680     new_blocks = [
# --> 681         blk.take_nd(
#     682             indexer,
#     683             axis=1,
#     684             fill_value=(
#     685                 fill_value if fill_value is not None else blk.fill_value
#     686             ),
#     687         )
#     688         for blk in self.blocks
#     689     ]
#     691 new_axes = list(self.axes)
#     692 new_axes[axis] = new_axis
#
# File /usr/lib/python3/dist-packages/pandas/core/internals/blocks.py:1144, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1141 else:
#    1142     allow_fill = True
# -> 1144 new_values = algos.take_nd(
#    1145     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1146 )
#    1148 # Called from three places in managers, all of which satisfy
#    1149 #  this assertion
#    1150 assert not (axis == 0 and new_mgr_locs is None)
#
# File /usr/lib/python3/dist-packages/pandas/core/array_algos/take.py:108, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     105     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     107 arr = np.asarray(arr)
# --> 108 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File /usr/lib/python3/dist-packages/pandas/core/array_algos/take.py:154, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     149     out = np.empty(out_shape, dtype=dtype)
#     151 func = _get_take_nd_function(
#     152     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     153 )
# --> 154 func(arr, indexer, out, fill_value)
#     156 if flip_order:
#     157     out = out.T
#
# KeyboardInterrupt:

# %%
rows = int(np.ceil(len(X_keys)/2))
cols = 2

fig, axes = plt.subplots(rows,cols,figsize=(11.69,17.44))
foo = 0

for i in range(rows):
    for j in range (cols):
        var = X_keys[foo]
        foo += 1
        ys = []
        for bar in xs:
            ys.append(lcurves[bar][var])
        
        axes[i,j].plot(xs,ys,'k.-')
        axes[i,j].set(xlabel=keys_dict[var],yticklabels=[],ylabel=None)

# %%
#print(plot_groups(posterior_df, X_keys, models, per_group=15))
for pergroup in [15,50,100]:
    print(kl_divergences(posterior_df, X_keys, models, per_group=int(pergroup),num_groups=20)['ppq'])
