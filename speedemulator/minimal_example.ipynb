# %% [markdown]
# # Minimal Example

# %% [markdown]
# First we train the surrogate model. To avoid over-fitting, we train `no_models` models, each with slightly different weights.

# %%
no_models = 4

# %%
emulator_dir = "minimal_example"
for model_index in range(no_models):
    # !python train_emulator.py --model_index {model_index} --emulator_dir {emulator_dir} --max_epochs 25
# Out:
# The following simulations are missing:
#    [337]
#   ... adjusting priors
#   Loading data sets...
# 499it [00:06, 77.07it/s]
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/nnemulator.py:291: RuntimeWarning: divide by zero encountered in log10
#   response = np.log10(response)
# Global seed set to 0
# Training model 0
# Generating eigenglaciers
# ...using the first 99 eigen values
# Generating eigenglaciers
# ...using the first 99 eigen values
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Adjusting learning rate of group 0 to 1.0000e-02.
#
#    | Name      | Type          | Params
# ---------------------------------------------
# 0  | l_1       | Linear        | 1.2 K
# 1  | norm_1    | LayerNorm     | 256
# 2  | dropout_1 | Dropout       | 0
# 3  | l_2       | Linear        | 16.5 K
# 4  | norm_2    | LayerNorm     | 256
# 5  | dropout_2 | Dropout       | 0
# 6  | l_3       | Linear        | 16.5 K
# 7  | norm_3    | LayerNorm     | 256
# 8  | dropout_3 | Dropout       | 0
# 9  | l_4       | Linear        | 16.5 K
# 10 | norm_4    | LayerNorm     | 256
# 11 | dropout_4 | Dropout       | 0
# 12 | l_5       | Linear        | 12.8 K
# 13 | train_ae  | AbsoluteError | 0
# 14 | test_ae   | AbsoluteError | 0
# ---------------------------------------------
# 64.5 K    Trainable params
# 2.6 M     Non-trainable params
# 2.7 M     Total params
# 10.753    Total estimated model params size (MB)
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/data_loading.py:326: UserWarning: The number of training samples (4) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  38%|█████▋         | 3/8 [00:07<00:09,  1.91s/it, loss=0.122, v_num=1]Adjusting learning rate of group 0 to 9.9750e-03.
# Epoch 0:  50%|███████       | 4/8 [00:08<00:06,  1.74s/it, loss=0.0939, v_num=1]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 0:  75%|██████████▌   | 6/8 [00:16<00:04,  2.30s/it, loss=0.0939, v_num=1]
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.14s/it]
# Epoch 0: 100%|██████████████| 8/8 [00:16<00:00,  1.83s/it, loss=0.0939, v_num=1]
# Epoch 0: 100%|█| 8/8 [00:17<00:00,  1.97s/it, loss=0.0939, v_num=1, train_loss=0
# Epoch 1:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.0745, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9501e-03.
# Epoch 1:  50%|▌| 4/8 [00:08<00:06,  1.70s/it, loss=0.0677, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 1:  75%|▊| 6/8 [00:15<00:04,  2.27s/it, loss=0.0677, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.15s/it]
# Epoch 1: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.0677, v_num=1, train_loss=0
# Epoch 1: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.0677, v_num=1, train_loss=0
# Epoch 2:  38%|▍| 3/8 [00:07<00:09,  1.87s/it, loss=0.0521, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9252e-03.
# Epoch 2:  50%|▌| 4/8 [00:08<00:06,  1.72s/it, loss=0.0488, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 2:  75%|▊| 6/8 [00:15<00:04,  2.25s/it, loss=0.0488, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.07s/it]
# Epoch 2: 100%|█| 8/8 [00:16<00:00,  1.80s/it, loss=0.0488, v_num=1, train_loss=0
# Epoch 2: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.0488, v_num=1, train_loss=0
# Epoch 3:  38%|▍| 3/8 [00:07<00:09,  1.85s/it, loss=0.0428, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9004e-03.
# Epoch 3:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.0407, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 3:  75%|▊| 6/8 [00:15<00:04,  2.23s/it, loss=0.0407, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.07s/it]
# Epoch 3: 100%|█| 8/8 [00:15<00:00,  1.78s/it, loss=0.0407, v_num=1, train_loss=0
# Epoch 3: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0407, v_num=1, train_loss=0
# Epoch 4:  38%|▍| 3/8 [00:07<00:09,  1.87s/it, loss=0.0355, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.8756e-03.
# Epoch 4:  50%|▌| 4/8 [00:08<00:06,  1.72s/it, loss=0.034, v_num=1, train_loss=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 4:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.034, v_num=1, train_loss=0.
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.15s/it]
# Epoch 4: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.034, v_num=1, train_loss=0.
# Epoch 4: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.034, v_num=1, train_loss=0.
# Epoch 5:  38%|▍| 3/8 [00:07<00:09,  1.89s/it, loss=0.017, v_num=1, train_loss=0.Adjusting learning rate of group 0 to 9.8509e-03.
# Epoch 5:  50%|▌| 4/8 [00:08<00:06,  1.75s/it, loss=0.0169, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 5:  75%|▊| 6/8 [00:16<00:04,  2.31s/it, loss=0.0169, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.18s/it]
# Epoch 5: 100%|█| 8/8 [00:16<00:00,  1.84s/it, loss=0.0169, v_num=1, train_loss=0
# Epoch 5: 100%|█| 8/8 [00:17<00:00,  1.97s/it, loss=0.0169, v_num=1, train_loss=0
# Epoch 6:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.0104, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.8263e-03.
# Epoch 6:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.00953, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 6:  75%|▊| 6/8 [00:15<00:04,  2.20s/it, loss=0.00953, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.02s/it]
# Epoch 6: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.00953, v_num=1, train_loss=
# Epoch 6: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.00953, v_num=1, train_loss=
# Epoch 7:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.00865, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.8017e-03.
# Epoch 7:  50%|▌| 4/8 [00:08<00:06,  1.73s/it, loss=0.00824, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 7:  75%|▊| 6/8 [00:16<00:04,  2.29s/it, loss=0.00824, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.15s/it]
# Epoch 7: 100%|█| 8/8 [00:16<00:00,  1.82s/it, loss=0.00824, v_num=1, train_loss=
# Epoch 7: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.00824, v_num=1, train_loss=
# Epoch 8:  38%|▍| 3/8 [00:07<00:09,  1.95s/it, loss=0.00604, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.7772e-03.
# Epoch 8:  50%|▌| 4/8 [00:08<00:07,  1.80s/it, loss=0.00568, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 8:  75%|▊| 6/8 [00:16<00:04,  2.37s/it, loss=0.00568, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.24s/it]
# Epoch 8: 100%|█| 8/8 [00:18<00:00,  2.01s/it, loss=0.00568, v_num=1, train_loss=
# Epoch 9:  38%|▍| 3/8 [00:07<00:09,  1.90s/it, loss=0.00499, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.7528e-03.
# Epoch 9:  50%|▌| 4/8 [00:08<00:06,  1.72s/it, loss=0.00488, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 9:  75%|▊| 6/8 [00:15<00:04,  2.25s/it, loss=0.00488, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.07s/it]
# Epoch 9: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00488, v_num=1, train_loss=
# Epoch 9: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00488, v_num=1, train_loss=
# Epoch 10:  38%|▍| 3/8 [00:07<00:08,  1.80s/it, loss=0.00403, v_num=1, train_lossAdjusting learning rate of group 0 to 9.7284e-03.
# Epoch 10:  50%|▌| 4/8 [00:08<00:06,  1.65s/it, loss=0.00378, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 10:  75%|▊| 6/8 [00:15<00:04,  2.21s/it, loss=0.00378, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.08s/it]
# Epoch 10: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.00378, v_num=1, train_loss
# Epoch 10: 100%|█| 8/8 [00:16<00:00,  1.89s/it, loss=0.00378, v_num=1, train_loss
# Epoch 11:  38%|▍| 3/8 [00:07<00:09,  1.86s/it, loss=0.00333, v_num=1, train_lossAdjusting learning rate of group 0 to 9.7041e-03.
# Epoch 11:  50%|▌| 4/8 [00:08<00:06,  1.70s/it, loss=0.00327, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 11:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.00327, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 11: 100%|█| 8/8 [00:16<00:00,  1.78s/it, loss=0.00327, v_num=1, train_loss
# Epoch 11: 100%|█| 8/8 [00:17<00:00,  1.89s/it, loss=0.00327, v_num=1, train_loss
# Epoch 12:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.00298, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6798e-03.
# Epoch 12:  50%|▌| 4/8 [00:08<00:06,  1.66s/it, loss=0.00285, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 12:  75%|▊| 6/8 [00:15<00:04,  2.19s/it, loss=0.00285, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.01s/it]
# Epoch 12: 100%|█| 8/8 [00:15<00:00,  1.75s/it, loss=0.00285, v_num=1, train_loss
# Epoch 12: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.00285, v_num=1, train_loss
# Epoch 13:  38%|▍| 3/8 [00:07<00:09,  1.86s/it, loss=0.00259, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6556e-03.
# Epoch 13:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.00255, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 13:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.00255, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.03s/it]
# Epoch 13: 100%|█| 8/8 [00:16<00:00,  1.78s/it, loss=0.00255, v_num=1, train_loss
# Epoch 13: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00255, v_num=1, train_loss
# Epoch 14:  38%|▍| 3/8 [00:07<00:09,  1.94s/it, loss=0.00246, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6315e-03.
# Epoch 14:  50%|▌| 4/8 [00:08<00:06,  1.75s/it, loss=0.0024, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 14:  75%|▊| 6/8 [00:15<00:04,  2.26s/it, loss=0.0024, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.02s/it]
# Epoch 14: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.0024, v_num=1, train_loss=
# Epoch 14: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.0024, v_num=1, train_loss=
# Epoch 15:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.00221, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6074e-03.
# Epoch 15:  50%|▌| 4/8 [00:08<00:06,  1.68s/it, loss=0.0022, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 15:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.0022, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.09s/it]
# Epoch 15: 100%|█| 8/8 [00:15<00:00,  1.78s/it, loss=0.0022, v_num=1, train_loss=
# Epoch 15: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0022, v_num=1, train_loss=
# Epoch 16:  38%|▍| 3/8 [00:07<00:09,  1.87s/it, loss=0.00209, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5834e-03.
# Epoch 16:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.00211, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 16:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.00211, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.03s/it]
# Epoch 16: 100%|█| 8/8 [00:15<00:00,  1.78s/it, loss=0.00211, v_num=1, train_loss
# Epoch 16: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00211, v_num=1, train_loss
# Epoch 17:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.002, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.5594e-03.
# Epoch 17:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.00197, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 17:  75%|▊| 6/8 [00:15<00:04,  2.20s/it, loss=0.00197, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.00s/it]
# Epoch 17: 100%|█| 8/8 [00:15<00:00,  1.75s/it, loss=0.00197, v_num=1, train_loss
# Epoch 17: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00197, v_num=1, train_loss
# Epoch 18:  38%|▍| 3/8 [00:07<00:09,  1.86s/it, loss=0.00189, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5355e-03.
# Epoch 18:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.00188, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 18:  75%|▊| 6/8 [00:15<00:04,  2.23s/it, loss=0.00188, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 18: 100%|█| 8/8 [00:15<00:00,  1.77s/it, loss=0.00188, v_num=1, train_loss
# Epoch 18: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00188, v_num=1, train_loss
# Epoch 19:  38%|▍| 3/8 [00:07<00:09,  1.81s/it, loss=0.00178, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5117e-03.
# Epoch 19:  50%|▌| 4/8 [00:08<00:06,  1.65s/it, loss=0.00178, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 19:  75%|▊| 6/8 [00:15<00:04,  2.21s/it, loss=0.00178, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.09s/it]
# Epoch 19: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.00178, v_num=1, train_loss
# Epoch 19: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.00178, v_num=1, train_loss
# Epoch 20:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.00171, v_num=1, train_lossAdjusting learning rate of group 0 to 9.4879e-03.
# Epoch 20:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.0017, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 20:  75%|▊| 6/8 [00:16<00:04,  2.33s/it, loss=0.0017, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.41s/it]
# Epoch 20: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.0017, v_num=1, train_loss=
# Epoch 20: 100%|█| 8/8 [00:17<00:00,  1.99s/it, loss=0.0017, v_num=1, train_loss=
# Epoch 21:  38%|▍| 3/8 [00:07<00:09,  1.96s/it, loss=0.00168, v_num=1, train_lossAdjusting learning rate of group 0 to 9.4642e-03.
# Epoch 21:  50%|▌| 4/8 [00:08<00:07,  1.79s/it, loss=0.00163, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 21:  75%|▊| 6/8 [00:16<00:04,  2.35s/it, loss=0.00163, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.21s/it]
# Epoch 21: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.00163, v_num=1, train_loss
# Epoch 21: 100%|█| 8/8 [00:17<00:00,  2.00s/it, loss=0.00163, v_num=1, train_loss
# Epoch 22:  38%|▍| 3/8 [00:08<00:10,  2.06s/it, loss=0.0016, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.4405e-03.
# Epoch 22:  50%|▌| 4/8 [00:09<00:07,  1.88s/it, loss=0.00159, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 22:  75%|▊| 6/8 [00:17<00:04,  2.43s/it, loss=0.00159, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.26s/it]
# Epoch 22: 100%|█| 8/8 [00:17<00:00,  1.93s/it, loss=0.00159, v_num=1, train_loss
# Epoch 22: 100%|█| 8/8 [00:18<00:00,  2.05s/it, loss=0.00159, v_num=1, train_loss
# Epoch 23:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.00155, v_num=1, train_lossAdjusting learning rate of group 0 to 9.4169e-03.
# Epoch 23:  50%|▌| 4/8 [00:08<00:06,  1.72s/it, loss=0.00154, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 23:  75%|▊| 6/8 [00:15<00:04,  2.26s/it, loss=0.00154, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 23: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00154, v_num=1, train_loss
# Epoch 23: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.00154, v_num=1, train_loss
# Epoch 24:  38%|▍| 3/8 [00:07<00:09,  1.89s/it, loss=0.00152, v_num=1, train_lossAdjusting learning rate of group 0 to 9.3934e-03.
# Epoch 24:  50%|▌| 4/8 [00:08<00:06,  1.73s/it, loss=0.00151, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 24:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.00151, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 24: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.00151, v_num=1, train_loss
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.93s/it, loss=0.00151, v_num=1, train_loss
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.93s/it, loss=0.00151, v_num=1, train_loss
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/utils.py:276: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb_ax.set_yticklabels([1, 10, 100, 1000])
# The following simulations are missing:
#    [337]
#   ... adjusting priors
#   Loading data sets...
# 499it [00:06, 78.72it/s]
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/nnemulator.py:291: RuntimeWarning: divide by zero encountered in log10
#   response = np.log10(response)
# Global seed set to 0
# Training model 1
# Generating eigenglaciers
# ...using the first 99 eigen values
# Generating eigenglaciers
# ...using the first 99 eigen values
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Adjusting learning rate of group 0 to 1.0000e-02.
#
#    | Name      | Type          | Params
# ---------------------------------------------
# 0  | l_1       | Linear        | 1.2 K
# 1  | norm_1    | LayerNorm     | 256
# 2  | dropout_1 | Dropout       | 0
# 3  | l_2       | Linear        | 16.5 K
# 4  | norm_2    | LayerNorm     | 256
# 5  | dropout_2 | Dropout       | 0
# 6  | l_3       | Linear        | 16.5 K
# 7  | norm_3    | LayerNorm     | 256
# 8  | dropout_3 | Dropout       | 0
# 9  | l_4       | Linear        | 16.5 K
# 10 | norm_4    | LayerNorm     | 256
# 11 | dropout_4 | Dropout       | 0
# 12 | l_5       | Linear        | 12.8 K
# 13 | train_ae  | AbsoluteError | 0
# 14 | test_ae   | AbsoluteError | 0
# ---------------------------------------------
# 64.5 K    Trainable params
# 2.6 M     Non-trainable params
# 2.7 M     Total params
# 10.753    Total estimated model params size (MB)
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/data_loading.py:326: UserWarning: The number of training samples (4) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  38%|█████▋         | 3/8 [00:07<00:09,  1.97s/it, loss=0.128, v_num=1]Adjusting learning rate of group 0 to 9.9750e-03.
# Epoch 0:  50%|███████       | 4/8 [00:08<00:07,  1.79s/it, loss=0.0988, v_num=1]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 0:  75%|██████████▌   | 6/8 [00:16<00:04,  2.32s/it, loss=0.0988, v_num=1]
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 0: 100%|██████████████| 8/8 [00:16<00:00,  1.84s/it, loss=0.0988, v_num=1]
# Epoch 0: 100%|█| 8/8 [00:17<00:00,  1.96s/it, loss=0.0988, v_num=1, train_loss=0
# Epoch 1:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.0765, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9501e-03.
# Epoch 1:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.0705, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 1:  75%|▊| 6/8 [00:15<00:04,  2.22s/it, loss=0.0705, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 1: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.0705, v_num=1, train_loss=0
# Epoch 1: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.0705, v_num=1, train_loss=0
# Epoch 2:  38%|▍| 3/8 [00:07<00:09,  1.83s/it, loss=0.0546, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9252e-03.
# Epoch 2:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.0509, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 2:  75%|▊| 6/8 [00:15<00:04,  2.20s/it, loss=0.0509, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:05,  2.97s/it]
# Epoch 2: 100%|█| 8/8 [00:15<00:00,  1.75s/it, loss=0.0509, v_num=1, train_loss=0
# Epoch 2: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.0509, v_num=1, train_loss=0
# Epoch 3:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.0443, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.9004e-03.
# Epoch 3:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.0423, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 3:  75%|▊| 6/8 [00:15<00:04,  2.21s/it, loss=0.0423, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.04s/it]
# Epoch 3: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.0423, v_num=1, train_loss=0
# Epoch 3: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.0423, v_num=1, train_loss=0
# Epoch 4:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.0368, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.8756e-03.
# Epoch 4:  50%|▌| 4/8 [00:08<00:06,  1.68s/it, loss=0.0352, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 4:  75%|▊| 6/8 [00:15<00:04,  2.17s/it, loss=0.0352, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:05,  2.95s/it]
# Epoch 4: 100%|█| 8/8 [00:15<00:00,  1.74s/it, loss=0.0352, v_num=1, train_loss=0
# Epoch 4: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.0352, v_num=1, train_loss=0
# Epoch 5:  38%|▍| 3/8 [00:07<00:09,  1.83s/it, loss=0.0172, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.8509e-03.
# Epoch 5:  50%|▌| 4/8 [00:08<00:06,  1.68s/it, loss=0.017, v_num=1, train_loss=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 5:  75%|▊| 6/8 [00:15<00:04,  2.20s/it, loss=0.017, v_num=1, train_loss=0.
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:05,  3.00s/it]
# Epoch 5: 100%|█| 8/8 [00:15<00:00,  1.75s/it, loss=0.017, v_num=1, train_loss=0.
# Epoch 5: 100%|█| 8/8 [00:16<00:00,  1.87s/it, loss=0.017, v_num=1, train_loss=0.
# Epoch 6:  38%|▍| 3/8 [00:07<00:09,  1.85s/it, loss=0.0109, v_num=1, train_loss=0Adjusting learning rate of group 0 to 9.8263e-03.
# Epoch 6:  50%|▌| 4/8 [00:08<00:06,  1.70s/it, loss=0.0096, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 6:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.0096, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 6: 100%|█| 8/8 [00:16<00:00,  1.78s/it, loss=0.0096, v_num=1, train_loss=0
# Epoch 6: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0096, v_num=1, train_loss=0
# Epoch 7:  38%|▍| 3/8 [00:07<00:09,  1.81s/it, loss=0.00844, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.8017e-03.
# Epoch 7:  50%|▌| 4/8 [00:08<00:06,  1.66s/it, loss=0.00811, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 7:  75%|▊| 6/8 [00:15<00:04,  2.22s/it, loss=0.00811, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.06s/it]
# Epoch 7: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.00811, v_num=1, train_loss=
# Epoch 7: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.00811, v_num=1, train_loss=
# Epoch 8:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.00613, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.7772e-03.
# Epoch 8:  50%|▌| 4/8 [00:08<00:06,  1.66s/it, loss=0.00565, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 8:  75%|▊| 6/8 [00:15<00:04,  2.21s/it, loss=0.00565, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 8: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.00565, v_num=1, train_loss=
# Epoch 8: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.00565, v_num=1, train_loss=
# Epoch 9:  38%|▍| 3/8 [00:08<00:11,  2.20s/it, loss=0.00496, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.7528e-03.
# Epoch 9:  50%|▌| 4/8 [00:10<00:08,  2.02s/it, loss=0.00486, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 9:  75%|▊| 6/8 [00:17<00:05,  2.54s/it, loss=0.00486, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.29s/it]
# Epoch 9: 100%|█| 8/8 [00:18<00:00,  2.02s/it, loss=0.00486, v_num=1, train_loss=
# Epoch 9: 100%|█| 8/8 [00:19<00:00,  2.14s/it, loss=0.00486, v_num=1, train_loss=
# Epoch 10:  38%|▍| 3/8 [00:07<00:09,  1.90s/it, loss=0.00414, v_num=1, train_lossAdjusting learning rate of group 0 to 9.7284e-03.
# Epoch 10:  50%|▌| 4/8 [00:08<00:06,  1.74s/it, loss=0.00391, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 10:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.00391, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.11s/it]
# Epoch 10: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.00391, v_num=1, train_loss
# Epoch 10: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.00391, v_num=1, train_loss
# Epoch 11:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.00335, v_num=1, train_lossAdjusting learning rate of group 0 to 9.7041e-03.
# Epoch 11:  50%|▌| 4/8 [00:08<00:06,  1.72s/it, loss=0.00332, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 11:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.00332, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.03s/it]
# Epoch 11: 100%|█| 8/8 [00:16<00:00,  1.78s/it, loss=0.00332, v_num=1, train_loss
# Epoch 11: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.00332, v_num=1, train_loss
# Epoch 12:  38%|▍| 3/8 [00:08<00:10,  2.02s/it, loss=0.00307, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6798e-03.
# Epoch 12:  50%|▌| 4/8 [00:09<00:07,  1.82s/it, loss=0.003, v_num=1, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 12:  75%|▊| 6/8 [00:16<00:04,  2.39s/it, loss=0.003, v_num=1, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.23s/it]
# Epoch 12: 100%|█| 8/8 [00:17<00:00,  1.89s/it, loss=0.003, v_num=1, train_loss=0
# Epoch 12: 100%|█| 8/8 [00:18<00:00,  2.02s/it, loss=0.003, v_num=1, train_loss=0
# Epoch 13:  38%|▍| 3/8 [00:08<00:10,  2.07s/it, loss=0.00266, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6556e-03.
# Epoch 13:  50%|▌| 4/8 [00:09<00:07,  1.85s/it, loss=0.00265, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 13:  75%|▊| 6/8 [00:16<00:04,  2.33s/it, loss=0.00265, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.03s/it]
# Epoch 13: 100%|█| 8/8 [00:16<00:00,  1.85s/it, loss=0.00265, v_num=1, train_loss
# Epoch 13: 100%|█| 8/8 [00:17<00:00,  1.97s/it, loss=0.00265, v_num=1, train_loss
# Epoch 14:  38%|▍| 3/8 [00:07<00:09,  1.86s/it, loss=0.00256, v_num=1, train_lossAdjusting learning rate of group 0 to 9.6315e-03.
# Epoch 14:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.0025, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 14:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.0025, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.14s/it]
# Epoch 14: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.0025, v_num=1, train_loss=
# Epoch 14: 100%|█| 8/8 [00:17<00:00,  1.93s/it, loss=0.0025, v_num=1, train_loss=
# Epoch 15:  38%|▍| 3/8 [00:07<00:09,  1.85s/it, loss=0.0023, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.6074e-03.
# Epoch 15:  50%|▌| 4/8 [00:08<00:06,  1.68s/it, loss=0.00228, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 15:  75%|▊| 6/8 [00:16<00:04,  2.34s/it, loss=0.00228, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.42s/it]
# Epoch 15: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00228, v_num=1, train_loss
# Epoch 15: 100%|█| 8/8 [00:17<00:00,  1.99s/it, loss=0.00228, v_num=1, train_loss
# Epoch 16:  38%|▍| 3/8 [00:09<00:11,  2.26s/it, loss=0.00219, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5834e-03.
# Epoch 16:  50%|▌| 4/8 [00:10<00:08,  2.05s/it, loss=0.00219, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 16:  75%|▊| 6/8 [00:18<00:05,  2.65s/it, loss=0.00219, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:07,  3.51s/it]
# Epoch 16: 100%|█| 8/8 [00:18<00:00,  2.09s/it, loss=0.00219, v_num=1, train_loss
# Epoch 16: 100%|█| 8/8 [00:20<00:00,  2.22s/it, loss=0.00219, v_num=1, train_loss
# Epoch 17:  38%|▍| 3/8 [00:08<00:10,  2.04s/it, loss=0.00206, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5594e-03.
# Epoch 17:  50%|▌| 4/8 [00:09<00:07,  1.85s/it, loss=0.00203, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 17:  75%|▊| 6/8 [00:16<00:04,  2.39s/it, loss=0.00203, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.19s/it]
# Epoch 17: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00203, v_num=1, train_loss
# Epoch 17: 100%|█| 8/8 [00:18<00:00,  2.03s/it, loss=0.00203, v_num=1, train_loss
# Epoch 18:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00194, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5355e-03.
# Epoch 18:  50%|▌| 4/8 [00:08<00:06,  1.75s/it, loss=0.00192, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 18:  75%|▊| 6/8 [00:15<00:04,  2.26s/it, loss=0.00192, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.01s/it]
# Epoch 18: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00192, v_num=1, train_loss
# Epoch 18: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.00192, v_num=1, train_loss
# Epoch 19:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00185, v_num=1, train_lossAdjusting learning rate of group 0 to 9.5117e-03.
# Epoch 19:  50%|▌| 4/8 [00:08<00:06,  1.74s/it, loss=0.00184, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 19:  75%|▊| 6/8 [00:16<00:04,  2.33s/it, loss=0.00184, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.25s/it]
# Epoch 19: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00184, v_num=1, train_loss
# Epoch 19: 100%|█| 8/8 [00:17<00:00,  1.99s/it, loss=0.00184, v_num=1, train_loss
# Epoch 20:  38%|▍| 3/8 [00:08<00:10,  2.07s/it, loss=0.0018, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.4879e-03.
# Epoch 20:  50%|▌| 4/8 [00:09<00:07,  1.90s/it, loss=0.00179, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 20:  75%|▊| 6/8 [00:18<00:05,  2.59s/it, loss=0.00179, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:07,  3.67s/it]
# Epoch 20: 100%|█| 8/8 [00:18<00:00,  2.06s/it, loss=0.00179, v_num=1, train_loss
# Epoch 20: 100%|█| 8/8 [00:19<00:00,  2.21s/it, loss=0.00179, v_num=1, train_loss
# Epoch 21:  38%|▍| 3/8 [00:08<00:10,  2.02s/it, loss=0.00175, v_num=1, train_lossAdjusting learning rate of group 0 to 9.4642e-03.
# Epoch 21:  50%|▌| 4/8 [00:09<00:07,  1.85s/it, loss=0.00173, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 21:  75%|▊| 6/8 [00:16<00:04,  2.41s/it, loss=0.00173, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.24s/it]
# Epoch 21: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.00173, v_num=1, train_loss
# Epoch 21: 100%|█| 8/8 [00:18<00:00,  2.04s/it, loss=0.00173, v_num=1, train_loss
# Epoch 22:  38%|▍| 3/8 [00:07<00:09,  1.94s/it, loss=0.0017, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.4405e-03.
# Epoch 22:  50%|▌| 4/8 [00:08<00:07,  1.79s/it, loss=0.0017, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 22:  75%|▊| 6/8 [00:16<00:04,  2.32s/it, loss=0.0017, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.13s/it]
# Epoch 22: 100%|█| 8/8 [00:16<00:00,  1.85s/it, loss=0.0017, v_num=1, train_loss=
# Epoch 22: 100%|█| 8/8 [00:17<00:00,  1.98s/it, loss=0.0017, v_num=1, train_loss=
# Epoch 23:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00164, v_num=1, train_lossAdjusting learning rate of group 0 to 9.4169e-03.
# Epoch 23:  50%|▌| 4/8 [00:08<00:06,  1.75s/it, loss=0.00164, v_num=1, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 23:  75%|▊| 6/8 [00:16<00:04,  2.29s/it, loss=0.00164, v_num=1, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.11s/it]
# Epoch 23: 100%|█| 8/8 [00:16<00:00,  1.82s/it, loss=0.00164, v_num=1, train_loss
# Epoch 23: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.00164, v_num=1, train_loss
# Epoch 24:  38%|▍| 3/8 [00:07<00:09,  1.82s/it, loss=0.0016, v_num=1, train_loss=Adjusting learning rate of group 0 to 9.3934e-03.
# Epoch 24:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.0016, v_num=1, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 24:  75%|▊| 6/8 [00:15<00:04,  2.22s/it, loss=0.0016, v_num=1, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.06s/it]
# Epoch 24: 100%|█| 8/8 [00:15<00:00,  1.77s/it, loss=0.0016, v_num=1, train_loss=
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.89s/it, loss=0.0016, v_num=1, train_loss=
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0016, v_num=1, train_loss=
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/utils.py:276: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb_ax.set_yticklabels([1, 10, 100, 1000])
# The following simulations are missing:
#    [337]
#   ... adjusting priors
#   Loading data sets...
# 499it [00:06, 81.67it/s]
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/nnemulator.py:291: RuntimeWarning: divide by zero encountered in log10
#   response = np.log10(response)
# Global seed set to 0
# Training model 2
# Generating eigenglaciers
# ...using the first 100 eigen values
# Generating eigenglaciers
# ...using the first 99 eigen values
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Adjusting learning rate of group 0 to 1.0000e-02.
#
#    | Name      | Type          | Params
# ---------------------------------------------
# 0  | l_1       | Linear        | 1.2 K
# 1  | norm_1    | LayerNorm     | 256
# 2  | dropout_1 | Dropout       | 0
# 3  | l_2       | Linear        | 16.5 K
# 4  | norm_2    | LayerNorm     | 256
# 5  | dropout_2 | Dropout       | 0
# 6  | l_3       | Linear        | 16.5 K
# 7  | norm_3    | LayerNorm     | 256
# 8  | dropout_3 | Dropout       | 0
# 9  | l_4       | Linear        | 16.5 K
# 10 | norm_4    | LayerNorm     | 256
# 11 | dropout_4 | Dropout       | 0
# 12 | l_5       | Linear        | 12.9 K
# 13 | train_ae  | AbsoluteError | 0
# 14 | test_ae   | AbsoluteError | 0
# ---------------------------------------------
# 64.6 K    Trainable params
# 2.6 M     Non-trainable params
# 2.7 M     Total params
# 10.858    Total estimated model params size (MB)
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/data_loading.py:326: UserWarning: The number of training samples (4) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  38%|█████▋         | 3/8 [00:07<00:09,  1.92s/it, loss=0.121, v_num=0]Adjusting learning rate of group 0 to 9.9750e-03.
# Epoch 0:  50%|███████       | 4/8 [00:08<00:07,  1.75s/it, loss=0.0948, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 0:  75%|██████████▌   | 6/8 [00:16<00:04,  2.30s/it, loss=0.0948, v_num=0]
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 0: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.0948, v_num=0, train_loss=0
# Epoch 1:  38%|▍| 3/8 [00:07<00:09,  1.81s/it, loss=0.0741, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9501e-03.
# Epoch 1:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.0679, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 1:  75%|▊| 6/8 [00:15<00:04,  2.22s/it, loss=0.0679, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.05s/it]
# Epoch 1: 100%|█| 8/8 [00:15<00:00,  1.76s/it, loss=0.0679, v_num=0, train_loss=0
# Epoch 1: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.0679, v_num=0, train_loss=0
# Epoch 2:  38%|▍| 3/8 [00:07<00:09,  1.94s/it, loss=0.0521, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9252e-03.
# Epoch 2:  50%|▌| 4/8 [00:08<00:07,  1.77s/it, loss=0.0485, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 2:  75%|▊| 6/8 [00:16<00:04,  2.32s/it, loss=0.0485, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.13s/it]
# Epoch 2: 100%|█| 8/8 [00:16<00:00,  1.84s/it, loss=0.0485, v_num=0, train_loss=0
# Epoch 2: 100%|█| 8/8 [00:17<00:00,  1.96s/it, loss=0.0485, v_num=0, train_loss=0
# Epoch 3:  38%|▍| 3/8 [00:08<00:10,  2.07s/it, loss=0.0426, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9004e-03.
# Epoch 3:  50%|▌| 4/8 [00:09<00:07,  1.88s/it, loss=0.0405, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 3:  75%|▊| 6/8 [00:17<00:05,  2.52s/it, loss=0.0405, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.49s/it]
# Epoch 3: 100%|█| 8/8 [00:17<00:00,  2.00s/it, loss=0.0405, v_num=0, train_loss=0
# Epoch 3: 100%|█| 8/8 [00:19<00:00,  2.12s/it, loss=0.0405, v_num=0, train_loss=0
# Epoch 4:  38%|▍| 3/8 [00:08<00:10,  2.17s/it, loss=0.0352, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.8756e-03.
# Epoch 4:  50%|▌| 4/8 [00:09<00:07,  1.96s/it, loss=0.0337, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 4:  75%|▊| 6/8 [00:17<00:04,  2.49s/it, loss=0.0337, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.26s/it]
# Epoch 4: 100%|█| 8/8 [00:17<00:00,  1.98s/it, loss=0.0337, v_num=0, train_loss=0
# Epoch 4: 100%|█| 8/8 [00:19<00:00,  2.12s/it, loss=0.0337, v_num=0, train_loss=0
# Epoch 5:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.0169, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.8509e-03.
# Epoch 5:  50%|▌| 4/8 [00:08<00:06,  1.73s/it, loss=0.0165, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 5:  75%|▊| 6/8 [00:15<00:04,  2.26s/it, loss=0.0165, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.04s/it]
# Epoch 5: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.0165, v_num=0, train_loss=0
# Epoch 5: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.0165, v_num=0, train_loss=0
# Epoch 6:  38%|▍| 3/8 [00:07<00:09,  1.83s/it, loss=0.0102, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.8263e-03.
# Epoch 6:  50%|▌| 4/8 [00:08<00:06,  1.67s/it, loss=0.00915, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 6:  75%|▊| 6/8 [00:15<00:04,  2.20s/it, loss=0.00915, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.01s/it]
# Epoch 6: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00915, v_num=0, train_loss=
# Epoch 7:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00833, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.8017e-03.
# Epoch 7:  50%|▌| 4/8 [00:08<00:07,  1.76s/it, loss=0.00814, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 7:  75%|▊| 6/8 [00:16<00:04,  2.31s/it, loss=0.00814, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.13s/it]
# Epoch 7: 100%|█| 8/8 [00:17<00:00,  1.95s/it, loss=0.00814, v_num=0, train_loss=
# Epoch 8:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.00587, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.7772e-03.
# Epoch 8:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.00552, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 8:  75%|▊| 6/8 [00:15<00:04,  2.25s/it, loss=0.00552, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 8: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00552, v_num=0, train_loss=
# Epoch 8: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.00552, v_num=0, train_loss=
# Epoch 9:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.00495, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.7528e-03.
# Epoch 9:  50%|▌| 4/8 [00:08<00:06,  1.68s/it, loss=0.0048, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 9:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.0048, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.21s/it]
# Epoch 9: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.0048, v_num=0, train_loss=0
# Epoch 9: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.0048, v_num=0, train_loss=0
# Epoch 10:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00388, v_num=0, train_lossAdjusting learning rate of group 0 to 9.7284e-03.
# Epoch 10:  50%|▌| 4/8 [00:08<00:07,  1.78s/it, loss=0.00371, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 10:  75%|▊| 6/8 [00:17<00:04,  2.45s/it, loss=0.00371, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.50s/it]
# Epoch 10: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.00371, v_num=0, train_loss
# Epoch 10: 100%|█| 8/8 [00:18<00:00,  2.07s/it, loss=0.00371, v_num=0, train_loss
# Epoch 11:  38%|▍| 3/8 [00:08<00:10,  2.11s/it, loss=0.00328, v_num=0, train_lossAdjusting learning rate of group 0 to 9.7041e-03.
# Epoch 11:  50%|▌| 4/8 [00:09<00:07,  1.92s/it, loss=0.00325, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 11:  75%|▊| 6/8 [00:17<00:05,  2.52s/it, loss=0.00325, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.41s/it]
# Epoch 11: 100%|█| 8/8 [00:17<00:00,  2.00s/it, loss=0.00325, v_num=0, train_loss
# Epoch 11: 100%|█| 8/8 [00:19<00:00,  2.12s/it, loss=0.00325, v_num=0, train_loss
# Epoch 12:  38%|▍| 3/8 [00:08<00:10,  2.04s/it, loss=0.00295, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6798e-03.
# Epoch 12:  50%|▌| 4/8 [00:09<00:07,  1.86s/it, loss=0.0028, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 12:  75%|▊| 6/8 [00:16<00:04,  2.40s/it, loss=0.0028, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.18s/it]
# Epoch 12: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0028, v_num=0, train_loss=
# Epoch 12: 100%|█| 8/8 [00:18<00:00,  2.02s/it, loss=0.0028, v_num=0, train_loss=
# Epoch 13:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.00251, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6556e-03.
# Epoch 13:  50%|▌| 4/8 [00:08<00:06,  1.70s/it, loss=0.00249, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 13:  75%|▊| 6/8 [00:15<00:04,  2.25s/it, loss=0.00249, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.09s/it]
# Epoch 13: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00249, v_num=0, train_loss
# Epoch 13: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.00249, v_num=0, train_loss
# Epoch 14:  38%|▍| 3/8 [00:07<00:09,  1.95s/it, loss=0.00238, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6315e-03.
# Epoch 14:  50%|▌| 4/8 [00:08<00:07,  1.78s/it, loss=0.00233, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 14:  75%|▊| 6/8 [00:16<00:04,  2.35s/it, loss=0.00233, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.20s/it]
# Epoch 14: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00233, v_num=0, train_loss
# Epoch 14: 100%|█| 8/8 [00:17<00:00,  1.99s/it, loss=0.00233, v_num=0, train_loss
# Epoch 15:  38%|▍| 3/8 [00:07<00:09,  1.92s/it, loss=0.00216, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6074e-03.
# Epoch 15:  50%|▌| 4/8 [00:08<00:07,  1.75s/it, loss=0.00211, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# ...
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.14s/it]
# Epoch 0: 100%|███████████████| 8/8 [00:16<00:00,  1.84s/it, loss=0.102, v_num=0]
# Epoch 0: 100%|█| 8/8 [00:17<00:00,  1.96s/it, loss=0.102, v_num=0, train_loss=0.
# Epoch 1:  38%|▍| 3/8 [00:07<00:09,  1.88s/it, loss=0.0808, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9501e-03.
# Epoch 1:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.0734, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 1:  75%|▊| 6/8 [00:15<00:04,  2.25s/it, loss=0.0734, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.08s/it]
# Epoch 1: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.0734, v_num=0, train_loss=0
# Epoch 1: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.0734, v_num=0, train_loss=0
# Epoch 2:  38%|▍| 3/8 [00:07<00:09,  1.84s/it, loss=0.0561, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9252e-03.
# Epoch 2:  50%|▌| 4/8 [00:08<00:06,  1.69s/it, loss=0.0526, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 2:  75%|▊| 6/8 [00:15<00:04,  2.24s/it, loss=0.0526, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.08s/it]
# Epoch 2: 100%|█| 8/8 [00:15<00:00,  1.78s/it, loss=0.0526, v_num=0, train_loss=0
# Epoch 2: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0526, v_num=0, train_loss=0
# Epoch 3:  38%|▍| 3/8 [00:07<00:09,  1.90s/it, loss=0.0455, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.9004e-03.
# Epoch 3:  50%|▌| 4/8 [00:08<00:06,  1.74s/it, loss=0.0431, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 3:  75%|▊| 6/8 [00:17<00:04,  2.45s/it, loss=0.0431, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:07,  3.57s/it]
# Epoch 3: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.0431, v_num=0, train_loss=0
# Epoch 3: 100%|█| 8/8 [00:18<00:00,  2.07s/it, loss=0.0431, v_num=0, train_loss=0
# Epoch 4:  38%|▍| 3/8 [00:08<00:10,  2.02s/it, loss=0.0373, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.8756e-03.
# Epoch 4:  50%|▌| 4/8 [00:09<00:07,  1.84s/it, loss=0.0357, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 4:  75%|▊| 6/8 [00:16<00:04,  2.39s/it, loss=0.0357, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.21s/it]
# Epoch 4: 100%|█| 8/8 [00:17<00:00,  1.90s/it, loss=0.0357, v_num=0, train_loss=0
# Epoch 4: 100%|█| 8/8 [00:18<00:00,  2.03s/it, loss=0.0357, v_num=0, train_loss=0
# Epoch 5:  38%|▍| 3/8 [00:07<00:09,  1.92s/it, loss=0.017, v_num=0, train_loss=0.Adjusting learning rate of group 0 to 9.8509e-03.
# Epoch 5:  50%|▌| 4/8 [00:08<00:06,  1.73s/it, loss=0.0168, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 5:  75%|▊| 6/8 [00:15<00:04,  2.28s/it, loss=0.0168, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.09s/it]
# Epoch 5: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.0168, v_num=0, train_loss=0
# Epoch 6:  38%|▍| 3/8 [00:07<00:09,  1.97s/it, loss=0.0096, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.8263e-03.
# Epoch 6:  50%|▌| 4/8 [00:09<00:07,  1.81s/it, loss=0.00867, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 6:  75%|▊| 6/8 [00:16<00:04,  2.39s/it, loss=0.00867, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.25s/it]
# Epoch 6: 100%|█| 8/8 [00:17<00:00,  1.89s/it, loss=0.00867, v_num=0, train_loss=
# Epoch 6: 100%|█| 8/8 [00:18<00:00,  2.02s/it, loss=0.00867, v_num=0, train_loss=
# Epoch 7:  38%|▍| 3/8 [00:07<00:09,  1.98s/it, loss=0.00791, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.8017e-03.
# Epoch 7:  50%|▌| 4/8 [00:09<00:07,  1.81s/it, loss=0.00737, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 7:  75%|▊| 6/8 [00:16<00:04,  2.34s/it, loss=0.00737, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 7: 100%|█| 8/8 [00:16<00:00,  1.85s/it, loss=0.00737, v_num=0, train_loss=
# Epoch 7: 100%|█| 8/8 [00:17<00:00,  1.97s/it, loss=0.00737, v_num=0, train_loss=
# Epoch 8:  38%|▍| 3/8 [00:07<00:09,  1.89s/it, loss=0.00534, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.7772e-03.
# Epoch 8:  50%|▌| 4/8 [00:08<00:06,  1.73s/it, loss=0.00507, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 8:  75%|▊| 6/8 [00:15<00:04,  2.27s/it, loss=0.00507, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.12s/it]
# Epoch 8: 100%|█| 8/8 [00:16<00:00,  1.81s/it, loss=0.00507, v_num=0, train_loss=
# Epoch 8: 100%|█| 8/8 [00:17<00:00,  1.93s/it, loss=0.00507, v_num=0, train_loss=
# Epoch 9:  38%|▍| 3/8 [00:07<00:09,  1.99s/it, loss=0.0046, v_num=0, train_loss=0Adjusting learning rate of group 0 to 9.7528e-03.
# Epoch 9:  50%|▌| 4/8 [00:09<00:07,  1.83s/it, loss=0.00449, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 9:  75%|▊| 6/8 [00:16<00:04,  2.42s/it, loss=0.00449, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.31s/it]
# Epoch 9: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.00449, v_num=0, train_loss=
# Epoch 9: 100%|█| 8/8 [00:18<00:00,  2.05s/it, loss=0.00449, v_num=0, train_loss=
# Epoch 10:  38%|▍| 3/8 [00:07<00:09,  1.87s/it, loss=0.00362, v_num=0, train_lossAdjusting learning rate of group 0 to 9.7284e-03.
# Epoch 10:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.00344, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 10:  75%|▊| 6/8 [00:15<00:04,  2.27s/it, loss=0.00344, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 10: 100%|█| 8/8 [00:16<00:00,  1.80s/it, loss=0.00344, v_num=0, train_loss
# Epoch 10: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.00344, v_num=0, train_loss
# Epoch 11:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00317, v_num=0, train_lossAdjusting learning rate of group 0 to 9.7041e-03.
# Epoch 11:  50%|▌| 4/8 [00:08<00:06,  1.74s/it, loss=0.00312, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 11:  75%|▊| 6/8 [00:16<00:04,  2.32s/it, loss=0.00312, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.21s/it]
# Epoch 11: 100%|█| 8/8 [00:16<00:00,  1.84s/it, loss=0.00312, v_num=0, train_loss
# Epoch 11: 100%|█| 8/8 [00:17<00:00,  1.97s/it, loss=0.00312, v_num=0, train_loss
# Epoch 12:  38%|▍| 3/8 [00:07<00:09,  1.93s/it, loss=0.00277, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6798e-03.
# Epoch 12:  50%|▌| 4/8 [00:08<00:07,  1.76s/it, loss=0.0027, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 12:  75%|▊| 6/8 [00:16<00:04,  2.30s/it, loss=0.0027, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.10s/it]
# Epoch 12: 100%|█| 8/8 [00:16<00:00,  1.83s/it, loss=0.0027, v_num=0, train_loss=
# Epoch 12: 100%|█| 8/8 [00:17<00:00,  1.95s/it, loss=0.0027, v_num=0, train_loss=
# Epoch 13:  38%|▍| 3/8 [00:07<00:09,  1.95s/it, loss=0.00251, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6556e-03.
# Epoch 13:  50%|▌| 4/8 [00:08<00:07,  1.80s/it, loss=0.0025, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 13:  75%|▊| 6/8 [00:16<00:04,  2.41s/it, loss=0.0025, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.34s/it]
# Epoch 13: 100%|█| 8/8 [00:17<00:00,  1.91s/it, loss=0.0025, v_num=0, train_loss=
# Epoch 13: 100%|█| 8/8 [00:18<00:00,  2.04s/it, loss=0.0025, v_num=0, train_loss=
# Epoch 14:  38%|▍| 3/8 [00:07<00:09,  1.99s/it, loss=0.00238, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6315e-03.
# Epoch 14:  50%|▌| 4/8 [00:09<00:07,  1.82s/it, loss=0.00233, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 14:  75%|▊| 6/8 [00:16<00:04,  2.37s/it, loss=0.00233, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.20s/it]
# Epoch 14: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.00233, v_num=0, train_loss
# Epoch 14: 100%|█| 8/8 [00:18<00:00,  2.01s/it, loss=0.00233, v_num=0, train_loss
# Epoch 15:  38%|▍| 3/8 [00:07<00:09,  2.00s/it, loss=0.00223, v_num=0, train_lossAdjusting learning rate of group 0 to 9.6074e-03.
# Epoch 15:  50%|▌| 4/8 [00:09<00:07,  1.82s/it, loss=0.0022, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 15:  75%|▊| 6/8 [00:16<00:04,  2.37s/it, loss=0.0022, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.18s/it]
# Epoch 15: 100%|█| 8/8 [00:16<00:00,  1.88s/it, loss=0.0022, v_num=0, train_loss=
# Epoch 15: 100%|█| 8/8 [00:18<00:00,  2.00s/it, loss=0.0022, v_num=0, train_loss=
# Epoch 16:  38%|▍| 3/8 [00:07<00:09,  1.89s/it, loss=0.00211, v_num=0, train_lossAdjusting learning rate of group 0 to 9.5834e-03.
# Epoch 16:  50%|▌| 4/8 [00:08<00:06,  1.71s/it, loss=0.00211, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 16:  75%|▊| 6/8 [00:16<00:04,  2.32s/it, loss=0.00211, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.25s/it]
# Epoch 16: 100%|█| 8/8 [00:16<00:00,  1.83s/it, loss=0.00211, v_num=0, train_loss
# Epoch 16: 100%|█| 8/8 [00:17<00:00,  1.96s/it, loss=0.00211, v_num=0, train_loss
# Epoch 17:  38%|▍| 3/8 [00:07<00:09,  1.91s/it, loss=0.00203, v_num=0, train_lossAdjusting learning rate of group 0 to 9.5594e-03.
# Epoch 17:  50%|▌| 4/8 [00:08<00:06,  1.75s/it, loss=0.002, v_num=0, train_loss=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 17:  75%|▊| 6/8 [00:16<00:04,  2.32s/it, loss=0.002, v_num=0, train_loss=0
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.23s/it]
# Epoch 17: 100%|█| 8/8 [00:16<00:00,  1.85s/it, loss=0.002, v_num=0, train_loss=0
# Epoch 17: 100%|█| 8/8 [00:17<00:00,  1.98s/it, loss=0.002, v_num=0, train_loss=0
# Epoch 18:  38%|▍| 3/8 [00:07<00:09,  1.92s/it, loss=0.00195, v_num=0, train_lossAdjusting learning rate of group 0 to 9.5355e-03.
# Epoch 18:  50%|▌| 4/8 [00:08<00:07,  1.76s/it, loss=0.00191, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 18:  75%|▊| 6/8 [00:16<00:04,  2.30s/it, loss=0.00191, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.09s/it]
# Epoch 18: 100%|█| 8/8 [00:16<00:00,  1.82s/it, loss=0.00191, v_num=0, train_loss
# Epoch 18: 100%|█| 8/8 [00:17<00:00,  1.94s/it, loss=0.00191, v_num=0, train_loss
# Epoch 19:  38%|▍| 3/8 [00:07<00:09,  1.87s/it, loss=0.00183, v_num=0, train_lossAdjusting learning rate of group 0 to 9.5117e-03.
# Epoch 19:  50%|▌| 4/8 [00:08<00:06,  1.70s/it, loss=0.00181, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 19:  75%|▊| 6/8 [00:15<00:04,  2.26s/it, loss=0.00181, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.11s/it]
# Epoch 19: 100%|█| 8/8 [00:16<00:00,  1.79s/it, loss=0.00181, v_num=0, train_loss
# Epoch 19: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.00181, v_num=0, train_loss
# Epoch 20:  38%|▍| 3/8 [00:08<00:11,  2.20s/it, loss=0.00176, v_num=0, train_lossAdjusting learning rate of group 0 to 9.4879e-03.
# Epoch 20:  50%|▌| 4/8 [00:09<00:07,  1.98s/it, loss=0.00176, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 20:  75%|▊| 6/8 [00:18<00:05,  2.58s/it, loss=0.00176, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:08<00:06,  3.45s/it]
# Epoch 20: 100%|█| 8/8 [00:18<00:00,  2.04s/it, loss=0.00176, v_num=0, train_loss
# Epoch 20: 100%|█| 8/8 [00:19<00:00,  2.17s/it, loss=0.00176, v_num=0, train_loss
# Epoch 21:  38%|▍| 3/8 [00:08<00:10,  2.03s/it, loss=0.00173, v_num=0, train_lossAdjusting learning rate of group 0 to 9.4642e-03.
# Epoch 21:  50%|▌| 4/8 [00:09<00:07,  1.85s/it, loss=0.0017, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 21:  75%|▊| 6/8 [00:16<00:04,  2.42s/it, loss=0.0017, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.25s/it]
# Epoch 21: 100%|█| 8/8 [00:17<00:00,  1.92s/it, loss=0.0017, v_num=0, train_loss=
# Epoch 21: 100%|█| 8/8 [00:18<00:00,  2.04s/it, loss=0.0017, v_num=0, train_loss=
# Epoch 22:  38%|▍| 3/8 [00:07<00:09,  1.96s/it, loss=0.00165, v_num=0, train_lossAdjusting learning rate of group 0 to 9.4405e-03.
# Epoch 22:  50%|▌| 4/8 [00:08<00:07,  1.80s/it, loss=0.00165, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 22:  75%|▊| 6/8 [00:16<00:04,  2.35s/it, loss=0.00165, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.17s/it]
# Epoch 22: 100%|█| 8/8 [00:16<00:00,  1.86s/it, loss=0.00165, v_num=0, train_loss
# Epoch 22: 100%|█| 8/8 [00:17<00:00,  1.98s/it, loss=0.00165, v_num=0, train_loss
# Epoch 23:  38%|▍| 3/8 [00:07<00:09,  1.89s/it, loss=0.0016, v_num=0, train_loss=Adjusting learning rate of group 0 to 9.4169e-03.
# Epoch 23:  50%|▌| 4/8 [00:08<00:06,  1.74s/it, loss=0.0016, v_num=0, train_loss=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 23:  75%|▊| 6/8 [00:16<00:04,  2.34s/it, loss=0.0016, v_num=0, train_loss=
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.26s/it]
# Epoch 23: 100%|█| 8/8 [00:16<00:00,  1.85s/it, loss=0.0016, v_num=0, train_loss=
# Epoch 23: 100%|█| 8/8 [00:17<00:00,  1.98s/it, loss=0.0016, v_num=0, train_loss=
# Epoch 24:  38%|▍| 3/8 [00:07<00:09,  1.93s/it, loss=0.00156, v_num=0, train_lossAdjusting learning rate of group 0 to 9.3934e-03.
# Epoch 24:  50%|▌| 4/8 [00:08<00:07,  1.77s/it, loss=0.00156, v_num=0, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Epoch 24:  75%|▊| 6/8 [00:16<00:04,  2.31s/it, loss=0.00156, v_num=0, train_loss
# Validating:  50%|████████████████▌                | 2/4 [00:07<00:06,  3.12s/it]
# Epoch 24: 100%|█| 8/8 [00:16<00:00,  1.83s/it, loss=0.00156, v_num=0, train_loss
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.95s/it, loss=0.00156, v_num=0, train_loss
# Epoch 24: 100%|█| 8/8 [00:17<00:00,  1.96s/it, loss=0.00156, v_num=0, train_loss
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/utils.py:276: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb_ax.set_yticklabels([1, 10, 100, 1000])

# %% [markdown]
# Show the first six eigen-glaciers for model 0

# %% [markdown]
# ![Eigen-glaciers](minimal_example/eigenglaciers/eigenglaciers_0.pdf)

# %% [markdown]
# Now we run the MALA Sampler, using only a short chain

# %%
for model_index in range(no_models):
    # !python sample_posterior_p.py --model_index {model_index} --emulator_dir {emulator_dir} --num_posterior_samples 20000
# Out:
# The following simulations are missing:
#    [337]
#   ... adjusting priors
#   Loading data sets...
# 499it [00:07, 64.61it/s]
# /Users/andy/Library/Python/3.9/lib/python/site-packages/pismemulator/nnemulator.py:291: RuntimeWarning: divide by zero encountered in log10
#   response = np.log10(response)
# ***********************************************
# ***********************************************
# Finding MAP point
# ***********************************************
# ***********************************************
# /Users/andy/base/pism-emulator/speedemulator/sample_posterior_p.py:97: UserWarning: torch.eig is deprecated in favor of torch.linalg.eig and will be removed in a future PyTorch release.
# torch.linalg.eig returns complex tensors of dtype cfloat or cdouble rather than real tensors mimicking complex tensors.
# L, _ = torch.eig(A)
# should be replaced with
# L_complex = torch.linalg.eigvals(A)
# and
# L, V = torch.eig(A, eigenvectors=True)
# should be replaced with
# L_complex, V_complex = torch.linalg.eig(A) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:2897.)
#   lamda, Q = torch.eig(H, eigenvectors=True)
# ===============================================
# iter: 0, log(P): 1251.4
#
# SIAE: 2.382
# SSAN: 3.232
# PPQ: 0.582
# TEFO: 0.019
# PHIMIN: 12.866
# PHIMAX: 42.460
# ZMIN: -511.795
# ZMAX: 492.324
#
# ===============================================
# ===============================================
# iter: 10, log(P): 1167.8
#
# SIAE: 2.370
# SSAN: 3.306
# PPQ: 0.539
# TEFO: 0.020
# PHIMIN: 13.237
# PHIMAX: 42.528
# ZMIN: -522.274
# ZMAX: 540.758
#
# ===============================================
# ===============================================
# iter: 20, log(P): 1167.3
#
# SIAE: 2.388
# SSAN: 3.305
# PPQ: 0.514
# TEFO: 0.021
# PHIMIN: 13.394
# PHIMAX: 42.683
# ZMIN: -536.361
# ZMAX: 585.233
#
# ===============================================
# ===============================================
# iter: 30, log(P): 1167.3
#
# SIAE: 2.400
# SSAN: 3.303
# PPQ: 0.503
# TEFO: 0.021
# PHIMIN: 13.052
# PHIMAX: 42.862
# ZMIN: -559.042
# ZMAX: 615.165
#
# ===============================================
# ===============================================
# iter: 40, log(P): 1167.3
#
# SIAE: 2.400
# SSAN: 3.303
# PPQ: 0.503
# TEFO: 0.021
# PHIMIN: 13.052
# PHIMAX: 42.862
# ZMIN: -559.042
# ZMAX: 615.165
#
# ===============================================
# ***********************************************
# ***********************************************
# Running Metropolis-Adjusted Langevin Algorithm for model index 0
# ***********************************************
# ***********************************************
# 20000
# ===============================================
# sample: 0, acc. rate: 0.25, log(P): 1167.3
# SIAE: 2.400
#  SSAN: 3.303
#  PPQ: 0.503
#  TEFO: 0.021
#  PHIMIN: 13.052
#  PHIMAX: 42.862
#  ZMIN: -559.042
#  ZMAX: 615.165
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 100, acc. rate: 0.32, log(P): 1174.7
# SIAE: 2.347
#  SSAN: 3.269
#  PPQ: 0.504
#  TEFO: 0.021
#  PHIMIN: 12.638
#  PHIMAX: 41.653
#  ZMIN: -606.173
#  ZMAX: 658.561
#
# ===============================================
# ===============================================
# sample: 200, acc. rate: 0.22, log(P): 1176.8
# SIAE: 2.049
#  SSAN: 3.289
#  PPQ: 0.586
#  TEFO: 0.020
#  PHIMIN: 15.862
#  PHIMAX: 40.213
#  ZMIN: -537.177
#  ZMAX: 548.425
#
# ===============================================
# ===============================================
# sample: 300, acc. rate: 0.23, log(P): 1170.9
# SIAE: 2.314
#  SSAN: 3.307
#  PPQ: 0.557
#  TEFO: 0.019
#  PHIMIN: 14.233
#  PHIMAX: 42.630
#  ZMIN: -521.100
#  ZMAX: 538.684
#
# ===============================================
# ===============================================
# sample: 400, acc. rate: 0.24, log(P): 1171.3
# SIAE: 2.365
#  SSAN: 3.193
#  PPQ: 0.465
#  TEFO: 0.023
#  PHIMIN: 12.246
#  PHIMAX: 42.006
#  ZMIN: -532.084
#  ZMAX: 636.201
#
# ===============================================
# ===============================================
# sample: 500, acc. rate: 0.32, log(P): 1170.2
# SIAE: 2.393
#  SSAN: 3.273
#  PPQ: 0.494
#  TEFO: 0.021
#  PHIMIN: 13.983
#  PHIMAX: 43.676
#  ZMIN: -613.664
#  ZMAX: 734.536
#
# ===============================================
# ===============================================
# sample: 600, acc. rate: 0.24, log(P): 1172.3
# SIAE: 2.213
#  SSAN: 3.302
#  PPQ: 0.590
#  TEFO: 0.021
#  PHIMIN: 12.578
#  PHIMAX: 41.911
#  ZMIN: -478.247
#  ZMAX: 606.588
#
# ===============================================
# ===============================================
# sample: 700, acc. rate: 0.19, log(P): 1169.7
# SIAE: 2.471
#  SSAN: 3.338
#  PPQ: 0.511
#  TEFO: 0.020
#  PHIMIN: 12.826
#  PHIMAX: 43.221
#  ZMIN: -626.078
#  ZMAX: 606.907
#
# ===============================================
# ===============================================
# sample: 800, acc. rate: 0.32, log(P): 1175.6
# SIAE: 2.355
#  SSAN: 3.278
#  PPQ: 0.622
#  TEFO: 0.021
#  PHIMIN: 13.245
#  PHIMAX: 41.903
#  ZMIN: -428.717
#  ZMAX: 460.375
#
# ===============================================
# ===============================================
# sample: 900, acc. rate: 0.25, log(P): 1171.6
# SIAE: 2.225
#  SSAN: 3.333
#  PPQ: 0.542
#  TEFO: 0.019
#  PHIMIN: 13.302
#  PHIMAX: 41.560
#  ZMIN: -546.419
#  ZMAX: 418.141
#
# ===============================================
# ===============================================
# sample: 1000, acc. rate: 0.18, log(P): 1171.3
# SIAE: 2.324
#  SSAN: 3.299
#  PPQ: 0.477
#  TEFO: 0.020
#  PHIMIN: 17.589
#  PHIMAX: 42.916
#  ZMIN: -434.922
#  ZMAX: 592.081
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 1100, acc. rate: 0.25, log(P): 1172.0
# SIAE: 2.461
#  SSAN: 3.295
#  PPQ: 0.566
#  TEFO: 0.019
#  PHIMIN: 14.003
#  PHIMAX: 43.205
#  ZMIN: -556.598
#  ZMAX: 520.362
#
# ===============================================
# ===============================================
# sample: 1200, acc. rate: 0.24, log(P): 1173.2
# SIAE: 2.467
#  SSAN: 3.254
#  PPQ: 0.553
#  TEFO: 0.022
#  PHIMIN: 11.391
#  PHIMAX: 43.304
#  ZMIN: -590.975
#  ZMAX: 669.635
#
# ===============================================
# ===============================================
# sample: 1300, acc. rate: 0.22, log(P): 1172.7
# SIAE: 2.497
#  SSAN: 3.229
#  PPQ: 0.481
#  TEFO: 0.024
#  PHIMIN: 11.775
#  PHIMAX: 44.511
#  ZMIN: -515.179
#  ZMAX: 728.779
#
# ===============================================
# ===============================================
# sample: 1400, acc. rate: 0.38, log(P): 1170.8
# SIAE: 2.259
#  SSAN: 3.280
#  PPQ: 0.525
#  TEFO: 0.022
#  PHIMIN: 13.939
#  PHIMAX: 41.570
#  ZMIN: -686.539
#  ZMAX: 775.706
#
# ===============================================
# ===============================================
# sample: 1500, acc. rate: 0.30, log(P): 1172.9
# SIAE: 2.402
#  SSAN: 3.350
#  PPQ: 0.552
#  TEFO: 0.023
#  PHIMIN: 17.192
#  PHIMAX: 40.806
#  ZMIN: -356.804
#  ZMAX: 674.201
#
# ===============================================
# ===============================================
# sample: 1600, acc. rate: 0.20, log(P): 1171.5
# SIAE: 2.373
#  SSAN: 3.285
#  PPQ: 0.489
#  TEFO: 0.023
#  PHIMIN: 12.367
#  PHIMAX: 44.331
#  ZMIN: -575.077
#  ZMAX: 843.862
#
# ===============================================
# ===============================================
# sample: 1700, acc. rate: 0.20, log(P): 1170.1
# SIAE: 2.301
#  SSAN: 3.313
#  PPQ: 0.516
#  TEFO: 0.019
#  PHIMIN: 13.729
#  PHIMAX: 42.637
#  ZMIN: -463.255
#  ZMAX: 438.054
#
# ===============================================
# ===============================================
# sample: 1800, acc. rate: 0.31, log(P): 1171.4
# SIAE: 2.329
#  SSAN: 3.314
#  PPQ: 0.525
#  TEFO: 0.020
#  PHIMIN: 10.732
#  PHIMAX: 42.777
#  ZMIN: -769.491
#  ZMAX: 614.510
#
# ===============================================
# ===============================================
# sample: 1900, acc. rate: 0.28, log(P): 1169.9
# SIAE: 2.446
#  SSAN: 3.327
#  PPQ: 0.526
#  TEFO: 0.022
#  PHIMIN: 13.915
#  PHIMAX: 42.444
#  ZMIN: -629.222
#  ZMAX: 653.556
#
# ===============================================
# ===============================================
# sample: 2000, acc. rate: 0.13, log(P): 1172.4
# SIAE: 2.336
#  SSAN: 3.334
#  PPQ: 0.506
#  TEFO: 0.022
#  PHIMIN: 14.653
#  PHIMAX: 40.690
#  ZMIN: -419.937
#  ZMAX: 497.325
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 2100, acc. rate: 0.25, log(P): 1170.5
# SIAE: 2.372
#  SSAN: 3.261
#  PPQ: 0.532
#  TEFO: 0.020
#  PHIMIN: 12.481
#  PHIMAX: 42.804
#  ZMIN: -502.446
#  ZMAX: 522.306
#
# ===============================================
# ===============================================
# sample: 2200, acc. rate: 0.31, log(P): 1170.2
# SIAE: 2.367
#  SSAN: 3.277
#  PPQ: 0.522
#  TEFO: 0.022
#  PHIMIN: 13.010
#  PHIMAX: 43.087
#  ZMIN: -495.304
#  ZMAX: 680.613
#
# ===============================================
# ===============================================
# sample: 2300, acc. rate: 0.23, log(P): 1173.4
# SIAE: 2.331
#  SSAN: 3.367
#  PPQ: 0.510
#  TEFO: 0.021
#  PHIMIN: 9.643
#  PHIMAX: 44.707
#  ZMIN: -650.316
#  ZMAX: 573.044
#
# ===============================================
# ===============================================
# sample: 2400, acc. rate: 0.27, log(P): 1170.1
# SIAE: 2.504
#  SSAN: 3.292
#  PPQ: 0.510
#  TEFO: 0.022
#  PHIMIN: 12.623
#  PHIMAX: 43.347
#  ZMIN: -528.656
#  ZMAX: 655.261
#
# ===============================================
# ===============================================
# sample: 2500, acc. rate: 0.26, log(P): 1170.3
# SIAE: 2.403
#  SSAN: 3.284
#  PPQ: 0.525
#  TEFO: 0.021
#  PHIMIN: 11.772
#  PHIMAX: 43.155
#  ZMIN: -648.617
#  ZMAX: 702.906
#
# ===============================================
# ===============================================
# sample: 2600, acc. rate: 0.29, log(P): 1171.9
# SIAE: 2.267
#  SSAN: 3.299
#  PPQ: 0.535
#  TEFO: 0.019
#  PHIMIN: 11.551
#  PHIMAX: 44.575
#  ZMIN: -591.661
#  ZMAX: 499.241
#
# ===============================================
# ===============================================
# sample: 2700, acc. rate: 0.28, log(P): 1171.1
# SIAE: 2.434
#  SSAN: 3.290
#  PPQ: 0.503
#  TEFO: 0.023
#  PHIMIN: 12.539
#  PHIMAX: 42.671
#  ZMIN: -773.743
#  ZMAX: 786.081
#
# ===============================================
# ===============================================
# sample: 2800, acc. rate: 0.21, log(P): 1169.7
# SIAE: 2.476
#  SSAN: 3.274
#  PPQ: 0.541
#  TEFO: 0.022
#  PHIMIN: 13.908
#  PHIMAX: 42.576
#  ZMIN: -500.454
#  ZMAX: 625.406
#
# ===============================================
# ===============================================
# sample: 2900, acc. rate: 0.31, log(P): 1171.6
# SIAE: 2.337
#  SSAN: 3.304
#  PPQ: 0.580
#  TEFO: 0.020
#  PHIMIN: 13.646
#  PHIMAX: 43.067
#  ZMIN: -506.483
#  ZMAX: 534.135
#
# ===============================================
# ===============================================
# sample: 3000, acc. rate: 0.23, log(P): 1171.2
# SIAE: 2.610
#  SSAN: 3.299
#  PPQ: 0.480
#  TEFO: 0.024
#  PHIMIN: 14.178
#  PHIMAX: 41.812
#  ZMIN: -544.565
#  ZMAX: 644.725
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 3100, acc. rate: 0.32, log(P): 1172.8
# SIAE: 2.419
#  SSAN: 3.318
#  PPQ: 0.551
#  TEFO: 0.020
#  PHIMIN: 13.801
#  PHIMAX: 44.421
#  ZMIN: -532.669
#  ZMAX: 612.096
#
# ===============================================
# ===============================================
# sample: 3200, acc. rate: 0.20, log(P): 1169.2
# SIAE: 2.531
#  SSAN: 3.305
#  PPQ: 0.498
#  TEFO: 0.023
#  PHIMIN: 14.245
#  PHIMAX: 42.625
#  ZMIN: -570.018
#  ZMAX: 723.160
#
# ===============================================
# ===============================================
# sample: 3300, acc. rate: 0.26, log(P): 1173.0
# SIAE: 2.271
#  SSAN: 3.382
#  PPQ: 0.448
#  TEFO: 0.022
#  PHIMIN: 12.813
#  PHIMAX: 44.505
#  ZMIN: -675.419
#  ZMAX: 870.922
#
# ===============================================
# ===============================================
# sample: 3400, acc. rate: 0.19, log(P): 1170.1
# SIAE: 2.494
#  SSAN: 3.349
#  PPQ: 0.450
#  TEFO: 0.021
#  PHIMIN: 11.219
#  PHIMAX: 43.413
#  ZMIN: -723.310
#  ZMAX: 650.960
#
# ===============================================
# ===============================================
# sample: 3500, acc. rate: 0.29, log(P): 1173.7
# SIAE: 2.214
#  SSAN: 3.365
#  PPQ: 0.373
#  TEFO: 0.021
#  PHIMIN: 7.173
#  PHIMAX: 44.386
#  ZMIN: -765.376
#  ZMAX: 600.375
#
# ===============================================
# ===============================================
# sample: 3600, acc. rate: 0.21, log(P): 1171.0
# SIAE: 2.361
#  SSAN: 3.285
#  PPQ: 0.554
#  TEFO: 0.019
#  PHIMIN: 11.124
#  PHIMAX: 42.991
#  ZMIN: -593.797
#  ZMAX: 500.251
#
# ===============================================
# ===============================================
# sample: 3700, acc. rate: 0.27, log(P): 1173.0
# SIAE: 2.254
#  SSAN: 3.259
#  PPQ: 0.454
#  TEFO: 0.020
#  PHIMIN: 14.935
#  PHIMAX: 44.280
#  ZMIN: -564.127
#  ZMAX: 726.107
#
# ===============================================
# ===============================================
# sample: 3800, acc. rate: 0.29, log(P): 1171.9
# SIAE: 2.251
#  SSAN: 3.214
#  PPQ: 0.425
#  TEFO: 0.024
#  PHIMIN: 14.258
#  PHIMAX: 41.340
#  ZMIN: -599.226
#  ZMAX: 839.229
#
# ===============================================
# ===============================================
# sample: 3900, acc. rate: 0.14, log(P): 1175.4
# SIAE: 2.663
#  SSAN: 3.249
#  PPQ: 0.494
#  TEFO: 0.022
#  PHIMIN: 16.798
#  PHIMAX: 43.332
#  ZMIN: -697.391
#  ZMAX: 767.232
#
# ===============================================
# ===============================================
# sample: 4000, acc. rate: 0.26, log(P): 1170.5
# SIAE: 2.280
#  SSAN: 3.262
#  PPQ: 0.531
#  TEFO: 0.020
#  PHIMIN: 13.838
#  PHIMAX: 41.373
#  ZMIN: -515.952
#  ZMAX: 489.741
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 4100, acc. rate: 0.25, log(P): 1174.2
# SIAE: 2.408
#  SSAN: 3.280
#  PPQ: 0.511
#  TEFO: 0.021
#  PHIMIN: 14.398
#  PHIMAX: 44.679
#  ZMIN: -455.337
#  ZMAX: 638.070
#
# ===============================================
# ===============================================
# sample: 4200, acc. rate: 0.21, log(P): 1171.3
# SIAE: 2.423
#  SSAN: 3.279
#  PPQ: 0.570
#  TEFO: 0.021
#  PHIMIN: 14.530
#  PHIMAX: 42.129
#  ZMIN: -493.144
#  ZMAX: 534.676
#
# ===============================================
# ===============================================
# sample: 4300, acc. rate: 0.23, log(P): 1172.3
# SIAE: 2.447
#  SSAN: 3.232
#  PPQ: 0.529
#  TEFO: 0.020
#  PHIMIN: 11.959
#  PHIMAX: 43.517
#  ZMIN: -621.414
#  ZMAX: 577.605
#
# ===============================================
# ===============================================
# sample: 4400, acc. rate: 0.30, log(P): 1170.0
# SIAE: 2.451
#  SSAN: 3.314
#  PPQ: 0.537
#  TEFO: 0.020
#  PHIMIN: 12.335
#  PHIMAX: 42.869
#  ZMIN: -674.592
#  ZMAX: 542.075
#
# ===============================================
# ===============================================
# sample: 4500, acc. rate: 0.22, log(P): 1169.2
# SIAE: 2.415
#  SSAN: 3.338
#  PPQ: 0.460
#  TEFO: 0.023
#  PHIMIN: 12.644
#  PHIMAX: 43.115
#  ZMIN: -502.490
#  ZMAX: 623.255
#
# ===============================================
# ===============================================
# sample: 4600, acc. rate: 0.15, log(P): 1169.2
# SIAE: 2.491
#  SSAN: 3.343
#  PPQ: 0.443
#  TEFO: 0.023
#  PHIMIN: 14.592
#  PHIMAX: 42.533
#  ZMIN: -536.746
#  ZMAX: 708.791
#
# ===============================================
# ===============================================
# sample: 4700, acc. rate: 0.31, log(P): 1169.3
# SIAE: 2.372
#  SSAN: 3.319
#  PPQ: 0.493
#  TEFO: 0.020
#  PHIMIN: 14.497
#  PHIMAX: 42.619
#  ZMIN: -492.420
#  ZMAX: 590.456
#
# ===============================================
# ===============================================
# sample: 4800, acc. rate: 0.22, log(P): 1169.7
# SIAE: 2.367
#  SSAN: 3.260
#  PPQ: 0.521
#  TEFO: 0.022
#  PHIMIN: 12.054
#  PHIMAX: 42.372
#  ZMIN: -542.911
#  ZMAX: 665.835
#
# ===============================================
# ===============================================
# sample: 4900, acc. rate: 0.30, log(P): 1171.3
# SIAE: 2.401
#  SSAN: 3.270
#  PPQ: 0.574
#  TEFO: 0.020
#  PHIMIN: 12.215
#  PHIMAX: 43.473
#  ZMIN: -604.401
#  ZMAX: 540.469
#
# ===============================================
# ===============================================
# sample: 5000, acc. rate: 0.22, log(P): 1174.7
# SIAE: 2.257
#  SSAN: 3.158
#  PPQ: 0.519
#  TEFO: 0.020
#  PHIMIN: 10.027
#  PHIMAX: 44.072
#  ZMIN: -591.307
#  ZMAX: 364.066
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 5100, acc. rate: 0.32, log(P): 1169.7
# SIAE: 2.434
#  SSAN: 3.284
#  PPQ: 0.517
#  TEFO: 0.020
#  PHIMIN: 13.633
#  PHIMAX: 44.002
#  ZMIN: -524.490
#  ZMAX: 555.519
#
# ===============================================
# ===============================================
# sample: 5200, acc. rate: 0.22, log(P): 1171.2
# SIAE: 2.264
#  SSAN: 3.276
#  PPQ: 0.471
#  TEFO: 0.021
#  PHIMIN: 9.890
#  PHIMAX: 42.719
#  ZMIN: -499.510
#  ZMAX: 521.160
#
# ===============================================
# ===============================================
# sample: 5300, acc. rate: 0.29, log(P): 1170.3
# SIAE: 2.333
#  SSAN: 3.308
#  PPQ: 0.535
#  TEFO: 0.019
#  PHIMIN: 14.022
#  PHIMAX: 43.029
#  ZMIN: -612.478
#  ZMAX: 561.077
#
# ===============================================
# ===============================================
# sample: 5400, acc. rate: 0.23, log(P): 1175.4
# SIAE: 2.343
#  SSAN: 3.191
#  PPQ: 0.556
#  TEFO: 0.022
#  PHIMIN: 10.744
#  PHIMAX: 41.949
#  ZMIN: -567.442
#  ZMAX: 497.985
#
# ===============================================
# ===============================================
# sample: 5500, acc. rate: 0.27, log(P): 1169.6
# SIAE: 2.339
#  SSAN: 3.311
#  PPQ: 0.524
#  TEFO: 0.020
#  PHIMIN: 12.380
#  PHIMAX: 42.966
#  ZMIN: -525.519
#  ZMAX: 561.723
#
# ===============================================
# ===============================================
# sample: 5600, acc. rate: 0.24, log(P): 1169.2
# SIAE: 2.474
#  SSAN: 3.323
#  PPQ: 0.474
#  TEFO: 0.023
#  PHIMIN: 15.186
#  PHIMAX: 41.840
#  ZMIN: -378.047
#  ZMAX: 587.202
#
# ===============================================
# ===============================================
# sample: 5700, acc. rate: 0.22, log(P): 1171.1
# SIAE: 2.401
#  SSAN: 3.248
#  PPQ: 0.566
#  TEFO: 0.021
#  PHIMIN: 13.045
#  PHIMAX: 42.619
#  ZMIN: -506.596
#  ZMAX: 593.207
#
# ===============================================
# ===============================================
# sample: 5800, acc. rate: 0.27, log(P): 1169.5
# SIAE: 2.473
#  SSAN: 3.318
#  PPQ: 0.504
#  TEFO: 0.021
#  PHIMIN: 13.724
#  PHIMAX: 43.391
#  ZMIN: -523.608
#  ZMAX: 597.467
#
# ===============================================
# ===============================================
# sample: 5900, acc. rate: 0.28, log(P): 1171.7
# SIAE: 2.251
#  SSAN: 3.294
#  PPQ: 0.510
#  TEFO: 0.021
#  PHIMIN: 16.320
#  PHIMAX: 42.568
#  ZMIN: -312.463
#  ZMAX: 572.007
#
# ===============================================
# ===============================================
# sample: 6000, acc. rate: 0.24, log(P): 1170.4
# SIAE: 2.514
#  SSAN: 3.283
#  PPQ: 0.455
#  TEFO: 0.025
#  PHIMIN: 14.903
#  PHIMAX: 41.960
#  ZMIN: -395.943
#  ZMAX: 754.942
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 6100, acc. rate: 0.29, log(P): 1173.3
# SIAE: 2.294
#  SSAN: 3.254
#  PPQ: 0.451
#  TEFO: 0.024
#  PHIMIN: 15.583
#  PHIMAX: 41.233
#  ZMIN: -572.512
#  ZMAX: 932.531
#
# ===============================================
# ===============================================
# sample: 6200, acc. rate: 0.23, log(P): 1169.9
# SIAE: 2.540
#  SSAN: 3.266
#  PPQ: 0.467
#  TEFO: 0.024
#  PHIMIN: 14.472
#  PHIMAX: 42.422
#  ZMIN: -524.534
#  ZMAX: 717.562
#
# ===============================================
# ===============================================
# sample: 6300, acc. rate: 0.25, log(P): 1173.1
# SIAE: 2.363
#  SSAN: 3.283
#  PPQ: 0.560
#  TEFO: 0.019
#  PHIMIN: 15.605
#  PHIMAX: 44.156
#  ZMIN: -667.872
#  ZMAX: 414.698
#
# ===============================================
# ===============================================
# sample: 6400, acc. rate: 0.19, log(P): 1171.7
# SIAE: 2.285
#  SSAN: 3.224
#  PPQ: 0.560
#  TEFO: 0.020
#  PHIMIN: 12.636
#  PHIMAX: 42.229
#  ZMIN: -454.051
#  ZMAX: 441.511
#
# ===============================================
# ===============================================
# sample: 6500, acc. rate: 0.35, log(P): 1179.7
# SIAE: 2.312
#  SSAN: 3.368
#  PPQ: 0.376
#  TEFO: 0.025
#  PHIMIN: 19.632
#  PHIMAX: 43.966
#  ZMIN: -209.165
#  ZMAX: 844.203
#
# ===============================================
# ===============================================
# sample: 6600, acc. rate: 0.26, log(P): 1170.0
# SIAE: 2.389
#  SSAN: 3.323
#  PPQ: 0.492
#  TEFO: 0.020
#  PHIMIN: 10.396
#  PHIMAX: 43.143
#  ZMIN: -706.410
#  ZMAX: 539.165
#
# ===============================================
# ===============================================
# sample: 6700, acc. rate: 0.25, log(P): 1171.3
# SIAE: 2.291
#  SSAN: 3.313
#  PPQ: 0.508
#  TEFO: 0.019
#  PHIMIN: 13.627
#  PHIMAX: 42.195
#  ZMIN: -478.271
#  ZMAX: 500.921
#
# ===============================================
# ===============================================
# sample: 6800, acc. rate: 0.29, log(P): 1172.0
# SIAE: 2.230
#  SSAN: 3.312
#  PPQ: 0.543
#  TEFO: 0.019
#  PHIMIN: 13.565
#  PHIMAX: 43.244
#  ZMIN: -699.164
#  ZMAX: 665.224
#
# ===============================================
# ===============================================
# sample: 6900, acc. rate: 0.16, log(P): 1168.3
# SIAE: 2.421
#  SSAN: 3.306
#  PPQ: 0.512
#  TEFO: 0.022
#  PHIMIN: 14.450
#  PHIMAX: 42.368
#  ZMIN: -496.855
#  ZMAX: 645.625
#
# ===============================================
# ===============================================
# sample: 7000, acc. rate: 0.26, log(P): 1177.6
# SIAE: 2.417
#  SSAN: 3.345
#  PPQ: 0.557
#  TEFO: 0.020
#  PHIMIN: 15.334
#  PHIMAX: 42.173
#  ZMIN: -263.842
#  ZMAX: 320.334
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 7100, acc. rate: 0.29, log(P): 1172.4
# SIAE: 2.266
#  SSAN: 3.263
#  PPQ: 0.544
#  TEFO: 0.020
#  PHIMIN: 14.417
#  PHIMAX: 42.899
#  ZMIN: -440.567
#  ZMAX: 594.916
#
# ===============================================
# ===============================================
# sample: 7200, acc. rate: 0.19, log(P): 1170.4
# SIAE: 2.446
#  SSAN: 3.308
#  PPQ: 0.526
#  TEFO: 0.021
#  PHIMIN: 12.093
#  PHIMAX: 43.095
#  ZMIN: -776.930
#  ZMAX: 670.386
#
# ===============================================
# ===============================================
# sample: 7300, acc. rate: 0.21, log(P): 1169.9
# SIAE: 2.480
#  SSAN: 3.355
#  PPQ: 0.475
#  TEFO: 0.021
#  PHIMIN: 11.978
#  PHIMAX: 43.599
#  ZMIN: -717.479
#  ZMAX: 696.199
#
# ===============================================
# ===============================================
# sample: 7400, acc. rate: 0.34, log(P): 1171.8
# SIAE: 2.205
#  SSAN: 3.298
#  PPQ: 0.531
#  TEFO: 0.019
#  PHIMIN: 10.466
#  PHIMAX: 41.904
#  ZMIN: -699.343
#  ZMAX: 525.274
#
# ===============================================
# ===============================================
# sample: 7500, acc. rate: 0.20, log(P): 1171.6
# SIAE: 2.383
#  SSAN: 3.287
#  PPQ: 0.524
#  TEFO: 0.021
#  PHIMIN: 12.077
#  PHIMAX: 41.651
#  ZMIN: -698.248
#  ZMAX: 590.989
#
# ===============================================
# ===============================================
# sample: 7600, acc. rate: 0.28, log(P): 1173.9
# SIAE: 2.501
#  SSAN: 3.253
#  PPQ: 0.551
#  TEFO: 0.020
#  PHIMIN: 14.667
#  PHIMAX: 42.769
#  ZMIN: -551.567
#  ZMAX: 526.561
#
# ===============================================
# ===============================================
# sample: 7700, acc. rate: 0.24, log(P): 1172.2
# SIAE: 2.400
#  SSAN: 3.269
#  PPQ: 0.557
#  TEFO: 0.022
#  PHIMIN: 14.473
#  PHIMAX: 41.521
#  ZMIN: -565.928
#  ZMAX: 729.129
#
# ===============================================
# ===============================================
# sample: 7800, acc. rate: 0.28, log(P): 1169.0
# SIAE: 2.409
#  SSAN: 3.323
#  PPQ: 0.475
#  TEFO: 0.021
#  PHIMIN: 14.666
#  PHIMAX: 43.607
#  ZMIN: -567.898
#  ZMAX: 675.310
#
# ===============================================
# ===============================================
# sample: 7900, acc. rate: 0.19, log(P): 1172.5
# SIAE: 2.406
#  SSAN: 3.218
#  PPQ: 0.410
#  TEFO: 0.025
#  PHIMIN: 8.677
#  PHIMAX: 42.815
#  ZMIN: -667.348
#  ZMAX: 620.416
#
# ===============================================
# ===============================================
# sample: 8000, acc. rate: 0.27, log(P): 1183.1
# SIAE: 2.069
#  SSAN: 3.366
#  PPQ: 0.479
#  TEFO: 0.023
#  PHIMIN: 8.550
#  PHIMAX: 41.790
#  ZMIN: -991.474
#  ZMAX: 772.179
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 8100, acc. rate: 0.27, log(P): 1172.9
# SIAE: 2.241
#  SSAN: 3.303
#  PPQ: 0.472
#  TEFO: 0.021
#  PHIMIN: 13.531
#  PHIMAX: 43.734
#  ZMIN: -703.786
#  ZMAX: 684.533
#
# ===============================================
# ===============================================
# sample: 8200, acc. rate: 0.18, log(P): 1172.9
# SIAE: 2.665
#  SSAN: 3.298
#  PPQ: 0.524
#  TEFO: 0.022
#  PHIMIN: 14.501
#  PHIMAX: 42.504
#  ZMIN: -606.699
#  ZMAX: 646.954
#
# ===============================================
# ===============================================
# sample: 8300, acc. rate: 0.26, log(P): 1173.0
# SIAE: 2.473
#  SSAN: 3.258
#  PPQ: 0.537
#  TEFO: 0.020
#  PHIMIN: 14.288
#  PHIMAX: 43.464
#  ZMIN: -551.330
#  ZMAX: 646.853
#
# ===============================================
# ===============================================
# sample: 8400, acc. rate: 0.25, log(P): 1178.2
# SIAE: 2.286
#  SSAN: 3.303
#  PPQ: 0.574
#  TEFO: 0.019
#  PHIMIN: 10.958
#  PHIMAX: 44.396
#  ZMIN: -479.909
#  ZMAX: 491.618
#
# ===============================================
# ===============================================
# sample: 8500, acc. rate: 0.22, log(P): 1172.1
# SIAE: 2.549
#  SSAN: 3.294
#  PPQ: 0.515
#  TEFO: 0.024
#  PHIMIN: 13.166
#  PHIMAX: 42.059
#  ZMIN: -392.087
#  ZMAX: 618.848
#
# ===============================================
# ===============================================
# sample: 8600, acc. rate: 0.21, log(P): 1175.1
# SIAE: 2.165
#  SSAN: 3.446
#  PPQ: 0.404
#  TEFO: 0.020
#  PHIMIN: 8.194
#  PHIMAX: 43.765
#  ZMIN: -865.807
#  ZMAX: 701.473
#
# ===============================================
# ===============================================
# sample: 8700, acc. rate: 0.28, log(P): 1172.5
# SIAE: 2.141
#  SSAN: 3.229
#  PPQ: 0.535
#  TEFO: 0.020
#  PHIMIN: 10.280
#  PHIMAX: 44.185
#  ZMIN: -617.470
#  ZMAX: 634.971
#
# ===============================================
# ===============================================
# sample: 8800, acc. rate: 0.20, log(P): 1170.7
# SIAE: 2.524
#  SSAN: 3.295
#  PPQ: 0.520
#  TEFO: 0.023
#  PHIMIN: 14.499
#  PHIMAX: 41.919
#  ZMIN: -459.883
#  ZMAX: 540.278
#
# ===============================================
# ===============================================
# sample: 8900, acc. rate: 0.24, log(P): 1176.1
# SIAE: 2.432
#  SSAN: 3.294
#  PPQ: 0.547
#  TEFO: 0.020
#  PHIMIN: 12.010
#  PHIMAX: 42.956
#  ZMIN: -521.213
#  ZMAX: 532.192
#
# ===============================================
# ===============================================
# sample: 9000, acc. rate: 0.38, log(P): 1169.3
# SIAE: 2.288
#  SSAN: 3.317
#  PPQ: 0.539
#  TEFO: 0.020
#  PHIMIN: 11.926
#  PHIMAX: 42.276
#  ZMIN: -645.594
#  ZMAX: 569.880
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 9100, acc. rate: 0.28, log(P): 1171.0
# SIAE: 2.253
#  SSAN: 3.277
#  PPQ: 0.395
#  TEFO: 0.021
#  PHIMIN: 8.740
#  PHIMAX: 42.871
#  ZMIN: -653.025
#  ZMAX: 506.371
#
# ===============================================
# ===============================================
# sample: 9200, acc. rate: 0.23, log(P): 1176.2
# SIAE: 2.224
#  SSAN: 3.287
#  PPQ: 0.542
#  TEFO: 0.022
#  PHIMIN: 7.136
#  PHIMAX: 42.007
#  ZMIN: -583.565
#  ZMAX: 528.115
#
# ===============================================
# ===============================================
# sample: 9300, acc. rate: 0.25, log(P): 1173.0
# SIAE: 2.327
#  SSAN: 3.223
#  PPQ: 0.476
#  TEFO: 0.025
#  PHIMIN: 11.935
#  PHIMAX: 42.895
#  ZMIN: -670.158
#  ZMAX: 934.853
#
# ===============================================
# ===============================================
# sample: 9400, acc. rate: 0.25, log(P): 1170.4
# SIAE: 2.357
#  SSAN: 3.330
#  PPQ: 0.544
#  TEFO: 0.020
#  PHIMIN: 15.612
#  PHIMAX: 42.386
#  ZMIN: -440.105
#  ZMAX: 579.239
#
# ===============================================
# ===============================================
# sample: 9500, acc. rate: 0.14, log(P): 1171.0
# SIAE: 2.131
#  SSAN: 3.337
#  PPQ: 0.542
#  TEFO: 0.020
#  PHIMIN: 13.529
#  PHIMAX: 41.745
#  ZMIN: -531.782
#  ZMAX: 556.776
#
# ===============================================
# ===============================================
# sample: 9600, acc. rate: 0.26, log(P): 1170.8
# SIAE: 2.419
#  SSAN: 3.361
#  PPQ: 0.537
#  TEFO: 0.021
#  PHIMIN: 14.255
#  PHIMAX: 42.318
#  ZMIN: -664.197
#  ZMAX: 628.701
#
# ===============================================
# ===============================================
# sample: 9700, acc. rate: 0.24, log(P): 1171.7
# SIAE: 2.382
#  SSAN: 3.342
#  PPQ: 0.478
#  TEFO: 0.021
#  PHIMIN: 15.887
#  PHIMAX: 41.794
#  ZMIN: -757.351
#  ZMAX: 664.623
#
# ===============================================
# ===============================================
# sample: 9800, acc. rate: 0.27, log(P): 1174.0
# SIAE: 2.454
#  SSAN: 3.227
#  PPQ: 0.493
#  TEFO: 0.020
#  PHIMIN: 9.768
#  PHIMAX: 44.069
#  ZMIN: -833.997
#  ZMAX: 642.698
#
# ===============================================
# ===============================================
# sample: 9900, acc. rate: 0.32, log(P): 1170.1
# SIAE: 2.467
#  SSAN: 3.275
#  PPQ: 0.499
#  TEFO: 0.024
#  PHIMIN: 15.362
#  PHIMAX: 41.525
#  ZMIN: -558.332
#  ZMAX: 759.063
#
# ===============================================
# ===============================================
# sample: 10000, acc. rate: 0.23, log(P): 1171.1
# SIAE: 2.413
#  SSAN: 3.337
#  PPQ: 0.495
#  TEFO: 0.022
#  PHIMIN: 18.471
#  PHIMAX: 42.069
#  ZMIN: -359.146
#  ZMAX: 633.138
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 10100, acc. rate: 0.29, log(P): 1171.4
# SIAE: 2.508
#  SSAN: 3.274
#  PPQ: 0.507
#  TEFO: 0.021
#  PHIMIN: 16.198
#  PHIMAX: 43.273
#  ZMIN: -534.141
#  ZMAX: 624.834
#
# ===============================================
# ===============================================
# sample: 10200, acc. rate: 0.17, log(P): 1170.5
# SIAE: 2.497
#  SSAN: 3.270
#  PPQ: 0.506
#  TEFO: 0.024
#  PHIMIN: 13.148
#  PHIMAX: 42.167
#  ZMIN: -488.772
#  ZMAX: 666.194
#
# ===============================================
# ===============================================
# sample: 10300, acc. rate: 0.27, log(P): 1173.4
# SIAE: 2.415
#  SSAN: 3.323
#  PPQ: 0.506
#  TEFO: 0.020
#  PHIMIN: 10.203
#  PHIMAX: 42.418
#  ZMIN: -630.424
#  ZMAX: 505.398
#
# ===============================================
# ===============================================
# sample: 10400, acc. rate: 0.23, log(P): 1171.7
# SIAE: 2.260
#  SSAN: 3.210
#  PPQ: 0.509
#  TEFO: 0.022
#  PHIMIN: 11.025
#  PHIMAX: 41.620
#  ZMIN: -630.786
#  ZMAX: 629.617
#
# ===============================================
# ===============================================
# sample: 10500, acc. rate: 0.26, log(P): 1172.9
# SIAE: 2.396
#  SSAN: 3.330
#  PPQ: 0.571
#  TEFO: 0.019
#  PHIMIN: 13.471
#  PHIMAX: 42.129
#  ZMIN: -660.025
#  ZMAX: 468.777
#
# ===============================================
# ===============================================
# sample: 10600, acc. rate: 0.25, log(P): 1177.4
# SIAE: 2.364
#  SSAN: 3.275
#  PPQ: 0.616
#  TEFO: 0.020
#  PHIMIN: 10.347
#  PHIMAX: 42.792
#  ZMIN: -653.840
#  ZMAX: 530.104
#
# ===============================================
# ===============================================
# sample: 10700, acc. rate: 0.25, log(P): 1172.1
# SIAE: 2.373
#  SSAN: 3.275
#  PPQ: 0.577
#  TEFO: 0.020
#  PHIMIN: 13.351
#  PHIMAX: 42.796
#  ZMIN: -488.331
#  ZMAX: 552.563
#
# ===============================================
# ===============================================
# sample: 10800, acc. rate: 0.27, log(P): 1169.0
# SIAE: 2.406
#  SSAN: 3.313
#  PPQ: 0.537
#  TEFO: 0.020
#  PHIMIN: 13.115
#  PHIMAX: 43.353
#  ZMIN: -580.610
#  ZMAX: 528.965
#
# ===============================================
# ===============================================
# sample: 10900, acc. rate: 0.18, log(P): 1168.9
# SIAE: 2.494
#  SSAN: 3.318
#  PPQ: 0.499
#  TEFO: 0.022
#  PHIMIN: 13.223
#  PHIMAX: 43.149
#  ZMIN: -494.079
#  ZMAX: 569.848
#
# ===============================================
# ===============================================
# sample: 11000, acc. rate: 0.28, log(P): 1171.5
# SIAE: 2.465
#  SSAN: 3.314
#  PPQ: 0.530
#  TEFO: 0.020
#  PHIMIN: 11.970
#  PHIMAX: 44.108
#  ZMIN: -713.022
#  ZMAX: 558.405
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 11100, acc. rate: 0.34, log(P): 1176.8
# SIAE: 2.350
#  SSAN: 3.277
#  PPQ: 0.484
#  TEFO: 0.021
#  PHIMIN: 19.298
#  PHIMAX: 43.877
#  ZMIN: -209.830
#  ZMAX: 307.822
#
# ===============================================
# ===============================================
# sample: 11200, acc. rate: 0.19, log(P): 1170.1
# SIAE: 2.328
#  SSAN: 3.341
#  PPQ: 0.524
#  TEFO: 0.019
#  PHIMIN: 15.307
#  PHIMAX: 42.843
#  ZMIN: -478.070
#  ZMAX: 499.736
#
# ===============================================
# ===============================================
# sample: 11300, acc. rate: 0.25, log(P): 1170.3
# SIAE: 2.443
#  SSAN: 3.306
#  PPQ: 0.532
#  TEFO: 0.021
#  PHIMIN: 14.481
#  PHIMAX: 43.216
#  ZMIN: -574.681
#  ZMAX: 682.343
#
# ===============================================
# ===============================================
# sample: 11400, acc. rate: 0.28, log(P): 1173.5
# SIAE: 2.315
#  SSAN: 3.252
#  PPQ: 0.548
#  TEFO: 0.018
#  PHIMIN: 14.293
#  PHIMAX: 42.437
#  ZMIN: -751.513
#  ZMAX: 504.185
#
# ===============================================
# ===============================================
# sample: 11500, acc. rate: 0.24, log(P): 1176.1
# SIAE: 2.146
#  SSAN: 3.272
#  PPQ: 0.517
#  TEFO: 0.020
#  PHIMIN: 9.115
#  PHIMAX: 42.328
#  ZMIN: -433.605
#  ZMAX: 228.768
#
# ===============================================
# ===============================================
# sample: 11600, acc. rate: 0.25, log(P): 1176.2
# SIAE: 2.449
#  SSAN: 3.293
#  PPQ: 0.523
#  TEFO: 0.018
#  PHIMIN: 13.928
#  PHIMAX: 44.768
#  ZMIN: -630.752
#  ZMAX: 427.204
#
# ===============================================
# ===============================================
# sample: 11700, acc. rate: 0.28, log(P): 1171.6
# SIAE: 2.449
#  SSAN: 3.267
#  PPQ: 0.480
#  TEFO: 0.021
#  PHIMIN: 11.988
#  PHIMAX: 43.973
#  ZMIN: -697.309
#  ZMAX: 701.018
#
# ===============================================
# ===============================================
# sample: 11800, acc. rate: 0.18, log(P): 1173.2
# SIAE: 2.653
#  SSAN: 3.286
#  PPQ: 0.457
#  TEFO: 0.022
#  PHIMIN: 16.241
#  PHIMAX: 43.847
#  ZMIN: -520.317
#  ZMAX: 693.649
#
# ===============================================
# ===============================================
# sample: 11900, acc. rate: 0.35, log(P): 1176.0
# SIAE: 2.623
#  SSAN: 3.297
#  PPQ: 0.544
#  TEFO: 0.022
#  PHIMIN: 16.062
#  PHIMAX: 41.607
#  ZMIN: -668.198
#  ZMAX: 703.983
#
# ===============================================
# ===============================================
# sample: 12000, acc. rate: 0.28, log(P): 1170.4
# SIAE: 2.485
#  SSAN: 3.248
#  PPQ: 0.410
#  TEFO: 0.024
#  PHIMIN: 13.799
#  PHIMAX: 43.056
#  ZMIN: -460.295
#  ZMAX: 684.726
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 12100, acc. rate: 0.21, log(P): 1174.5
# SIAE: 2.290
#  SSAN: 3.245
#  PPQ: 0.432
#  TEFO: 0.024
#  PHIMIN: 6.830
#  PHIMAX: 43.782
#  ZMIN: -526.315
#  ZMAX: 509.588
#
# ===============================================
# ===============================================
# sample: 12200, acc. rate: 0.24, log(P): 1171.1
# SIAE: 2.367
#  SSAN: 3.316
#  PPQ: 0.483
#  TEFO: 0.021
#  PHIMIN: 13.285
#  PHIMAX: 41.220
#  ZMIN: -598.348
#  ZMAX: 581.964
#
# ===============================================
# ===============================================
# sample: 12300, acc. rate: 0.33, log(P): 1177.5
# SIAE: 2.149
#  SSAN: 3.248
#  PPQ: 0.445
#  TEFO: 0.023
#  PHIMIN: 14.407
#  PHIMAX: 40.869
#  ZMIN: -305.948
#  ZMAX: 662.421
#
# ===============================================
# ===============================================
# sample: 12400, acc. rate: 0.18, log(P): 1171.7
# SIAE: 2.489
#  SSAN: 3.284
#  PPQ: 0.565
#  TEFO: 0.020
#  PHIMIN: 13.650
#  PHIMAX: 43.139
#  ZMIN: -577.402
#  ZMAX: 543.707
#
# ===============================================
# ===============================================
# sample: 12500, acc. rate: 0.28, log(P): 1170.3
# SIAE: 2.361
#  SSAN: 3.278
#  PPQ: 0.530
#  TEFO: 0.020
#  PHIMIN: 14.089
#  PHIMAX: 41.892
#  ZMIN: -550.872
#  ZMAX: 502.215
#
# ===============================================
# ===============================================
# sample: 12600, acc. rate: 0.25, log(P): 1173.1
# SIAE: 2.345
#  SSAN: 3.266
#  PPQ: 0.524
#  TEFO: 0.020
#  PHIMIN: 12.817
#  PHIMAX: 44.127
#  ZMIN: -624.227
#  ZMAX: 765.785
#
# ===============================================
# ===============================================
# sample: 12700, acc. rate: 0.26, log(P): 1171.6
# SIAE: 2.379
#  SSAN: 3.247
#  PPQ: 0.501
#  TEFO: 0.021
#  PHIMIN: 14.836
#  PHIMAX: 44.026
#  ZMIN: -437.952
#  ZMAX: 622.763
#
# ===============================================
# ===============================================
# sample: 12800, acc. rate: 0.24, log(P): 1171.3
# SIAE: 2.681
#  SSAN: 3.294
#  PPQ: 0.445
#  TEFO: 0.023
#  PHIMIN: 13.664
#  PHIMAX: 43.300
#  ZMIN: -569.230
#  ZMAX: 641.091
#
# ===============================================
# ===============================================
# sample: 12900, acc. rate: 0.24, log(P): 1171.1
# SIAE: 2.339
#  SSAN: 3.339
#  PPQ: 0.532
#  TEFO: 0.019
#  PHIMIN: 11.722
#  PHIMAX: 43.302
#  ZMIN: -654.962
#  ZMAX: 547.798
#
# ===============================================
# ===============================================
# sample: 13000, acc. rate: 0.25, log(P): 1178.1
# SIAE: 2.654
#  SSAN: 3.322
#  PPQ: 0.302
#  TEFO: 0.022
#  PHIMIN: 13.307
#  PHIMAX: 43.474
#  ZMIN: -877.738
#  ZMAX: 799.617
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 13100, acc. rate: 0.16, log(P): 1174.8
# SIAE: 2.441
#  SSAN: 3.192
#  PPQ: 0.581
#  TEFO: 0.023
#  PHIMIN: 13.876
#  PHIMAX: 42.774
#  ZMIN: -632.342
#  ZMAX: 840.742
#
# ===============================================
# ===============================================
# sample: 13200, acc. rate: 0.29, log(P): 1174.2
# SIAE: 2.522
#  SSAN: 3.287
#  PPQ: 0.521
#  TEFO: 0.021
#  PHIMIN: 12.097
#  PHIMAX: 44.508
#  ZMIN: -664.769
#  ZMAX: 713.422
#
# ===============================================
# ===============================================
# sample: 13300, acc. rate: 0.24, log(P): 1172.6
# SIAE: 2.466
#  SSAN: 3.345
#  PPQ: 0.470
#  TEFO: 0.024
#  PHIMIN: 17.449
#  PHIMAX: 43.514
#  ZMIN: -462.247
#  ZMAX: 870.199
#
# ===============================================
# ===============================================
# sample: 13400, acc. rate: 0.23, log(P): 1179.2
# SIAE: 2.261
#  SSAN: 3.323
#  PPQ: 0.512
#  TEFO: 0.020
#  PHIMIN: 12.451
#  PHIMAX: 44.965
#  ZMIN: -544.795
#  ZMAX: 544.095
#
# ===============================================
# ===============================================
# sample: 13500, acc. rate: 0.25, log(P): 1175.1
# SIAE: 2.419
#  SSAN: 3.359
#  PPQ: 0.459
#  TEFO: 0.021
#  PHIMIN: 9.443
#  PHIMAX: 44.884
#  ZMIN: -721.752
#  ZMAX: 637.966
#
# ===============================================
# ===============================================
# sample: 13600, acc. rate: 0.26, log(P): 1169.9
# SIAE: 2.460
#  SSAN: 3.295
#  PPQ: 0.511
#  TEFO: 0.021
#  PHIMIN: 14.367
#  PHIMAX: 44.026
#  ZMIN: -592.740
#  ZMAX: 688.032
#
# ===============================================
# ===============================================
# sample: 13700, acc. rate: 0.25, log(P): 1171.5
# SIAE: 2.269
#  SSAN: 3.275
#  PPQ: 0.588
#  TEFO: 0.020
#  PHIMIN: 12.678
#  PHIMAX: 41.818
#  ZMIN: -507.357
#  ZMAX: 474.567
#
# ===============================================
# ===============================================
# sample: 13800, acc. rate: 0.19, log(P): 1170.8
# SIAE: 2.251
#  SSAN: 3.341
#  PPQ: 0.482
#  TEFO: 0.021
#  PHIMIN: 10.990
#  PHIMAX: 42.344
#  ZMIN: -757.475
#  ZMAX: 728.012
#
# ===============================================
# ===============================================
# sample: 13900, acc. rate: 0.24, log(P): 1170.9
# SIAE: 2.660
#  SSAN: 3.338
#  PPQ: 0.477
#  TEFO: 0.024
#  PHIMIN: 16.451
#  PHIMAX: 42.688
#  ZMIN: -564.860
#  ZMAX: 722.248
#
# ===============================================
# ===============================================
# sample: 14000, acc. rate: 0.32, log(P): 1170.2
# SIAE: 2.354
#  SSAN: 3.295
#  PPQ: 0.547
#  TEFO: 0.020
#  PHIMIN: 12.300
#  PHIMAX: 42.667
#  ZMIN: -483.620
#  ZMAX: 469.761
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 14100, acc. rate: 0.20, log(P): 1169.7
# SIAE: 2.254
#  SSAN: 3.279
#  PPQ: 0.522
#  TEFO: 0.022
#  PHIMIN: 12.569
#  PHIMAX: 43.192
#  ZMIN: -570.005
#  ZMAX: 747.751
#
# ===============================================
# ===============================================
# sample: 14200, acc. rate: 0.18, log(P): 1170.7
# SIAE: 2.552
#  SSAN: 3.297
#  PPQ: 0.531
#  TEFO: 0.021
#  PHIMIN: 13.714
#  PHIMAX: 42.531
#  ZMIN: -561.115
#  ZMAX: 555.763
#
# ===============================================
# ===============================================
# sample: 14300, acc. rate: 0.27, log(P): 1175.6
# SIAE: 2.397
#  SSAN: 3.237
#  PPQ: 0.603
#  TEFO: 0.022
#  PHIMIN: 16.815
#  PHIMAX: 41.635
#  ZMIN: -347.894
#  ZMAX: 551.127
#
# ===============================================
# ===============================================
# sample: 14400, acc. rate: 0.30, log(P): 1172.3
# SIAE: 2.365
#  SSAN: 3.282
#  PPQ: 0.585
#  TEFO: 0.020
#  PHIMIN: 13.967
#  PHIMAX: 43.405
#  ZMIN: -486.784
#  ZMAX: 533.803
#
# ===============================================
# ===============================================
# sample: 14500, acc. rate: 0.25, log(P): 1169.5
# SIAE: 2.398
#  SSAN: 3.297
#  PPQ: 0.511
#  TEFO: 0.022
#  PHIMIN: 13.554
#  PHIMAX: 43.069
#  ZMIN: -680.993
#  ZMAX: 796.288
#
# ===============================================
# ===============================================
# sample: 14600, acc. rate: 0.22, log(P): 1172.2
# SIAE: 2.402
#  SSAN: 3.318
#  PPQ: 0.451
#  TEFO: 0.025
#  PHIMIN: 10.725
#  PHIMAX: 43.102
#  ZMIN: -802.161
#  ZMAX: 830.518
#
# ===============================================
# ===============================================
# sample: 14700, acc. rate: 0.26, log(P): 1174.5
# SIAE: 2.253
#  SSAN: 3.328
#  PPQ: 0.552
#  TEFO: 0.020
#  PHIMIN: 14.041
#  PHIMAX: 41.662
#  ZMIN: -371.628
#  ZMAX: 481.576
#
# ===============================================
# ===============================================
# sample: 14800, acc. rate: 0.24, log(P): 1171.6
# SIAE: 2.209
#  SSAN: 3.191
#  PPQ: 0.543
#  TEFO: 0.018
#  PHIMIN: 13.553
#  PHIMAX: 43.238
#  ZMIN: -550.430
#  ZMAX: 426.026
#
# ===============================================
# ===============================================
# sample: 14900, acc. rate: 0.29, log(P): 1173.2
# SIAE: 2.223
#  SSAN: 3.195
#  PPQ: 0.545
#  TEFO: 0.019
#  PHIMIN: 11.687
#  PHIMAX: 42.675
#  ZMIN: -514.697
#  ZMAX: 493.247
#
# ===============================================
# ===============================================
# sample: 15000, acc. rate: 0.29, log(P): 1177.9
# SIAE: 2.019
#  SSAN: 3.377
#  PPQ: 0.413
#  TEFO: 0.025
#  PHIMIN: 5.735
#  PHIMAX: 42.554
#  ZMIN: -864.352
#  ZMAX: 800.815
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 15100, acc. rate: 0.26, log(P): 1173.4
# SIAE: 2.317
#  SSAN: 3.391
#  PPQ: 0.497
#  TEFO: 0.023
#  PHIMIN: 12.463
#  PHIMAX: 44.115
#  ZMIN: -580.101
#  ZMAX: 822.702
#
# ===============================================
# ===============================================
# sample: 15200, acc. rate: 0.24, log(P): 1171.0
# SIAE: 2.376
#  SSAN: 3.316
#  PPQ: 0.403
#  TEFO: 0.024
#  PHIMIN: 13.810
#  PHIMAX: 43.854
#  ZMIN: -509.124
#  ZMAX: 825.010
#
# ===============================================
# ===============================================
# sample: 15300, acc. rate: 0.20, log(P): 1169.0
# SIAE: 2.420
#  SSAN: 3.279
#  PPQ: 0.540
#  TEFO: 0.021
#  PHIMIN: 12.586
#  PHIMAX: 42.871
#  ZMIN: -635.463
#  ZMAX: 640.918
#
# ===============================================
# ===============================================
# sample: 15400, acc. rate: 0.26, log(P): 1172.9
# SIAE: 2.233
#  SSAN: 3.340
#  PPQ: 0.441
#  TEFO: 0.023
#  PHIMIN: 10.809
#  PHIMAX: 40.499
#  ZMIN: -656.733
#  ZMAX: 498.525
#
# ===============================================
# ===============================================
# sample: 15500, acc. rate: 0.25, log(P): 1170.8
# SIAE: 2.469
#  SSAN: 3.348
#  PPQ: 0.440
#  TEFO: 0.024
#  PHIMIN: 12.445
#  PHIMAX: 43.000
#  ZMIN: -480.216
#  ZMAX: 693.535
#
# ===============================================
# ===============================================
# sample: 15600, acc. rate: 0.23, log(P): 1172.7
# SIAE: 2.246
#  SSAN: 3.207
#  PPQ: 0.497
#  TEFO: 0.021
#  PHIMIN: 9.359
#  PHIMAX: 44.404
#  ZMIN: -649.356
#  ZMAX: 706.128
#
# ===============================================
# ===============================================
# sample: 15700, acc. rate: 0.23, log(P): 1171.4
# SIAE: 2.371
#  SSAN: 3.274
#  PPQ: 0.525
#  TEFO: 0.021
#  PHIMIN: 16.978
#  PHIMAX: 41.733
#  ZMIN: -518.240
#  ZMAX: 699.702
#
# ===============================================
# ===============================================
# sample: 15800, acc. rate: 0.29, log(P): 1174.0
# SIAE: 2.687
#  SSAN: 3.295
#  PPQ: 0.438
#  TEFO: 0.023
#  PHIMIN: 11.639
#  PHIMAX: 42.800
#  ZMIN: -750.957
#  ZMAX: 654.582
#
# ===============================================
# ===============================================
# sample: 15900, acc. rate: 0.22, log(P): 1169.1
# SIAE: 2.394
#  SSAN: 3.339
#  PPQ: 0.516
#  TEFO: 0.021
#  PHIMIN: 15.427
#  PHIMAX: 42.195
#  ZMIN: -541.743
#  ZMAX: 623.865
#
# ===============================================
# ===============================================
# sample: 16000, acc. rate: 0.25, log(P): 1171.1
# SIAE: 2.034
#  SSAN: 3.293
#  PPQ: 0.505
#  TEFO: 0.020
#  PHIMIN: 11.950
#  PHIMAX: 41.640
#  ZMIN: -656.614
#  ZMAX: 630.064
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 0
# ///////////////////////////////////////////////
# ===============================================
# sample: 16100, acc. rate: 0.31, log(P): 1171.7
# SIAE: 2.426
#  SSAN: 3.361
#  PPQ: 0.395
#  TEFO: 0.022
#  PHIMIN: 10.802
#  PHIMAX: 43.823
#  ZMIN: -847.117
#  ZMAX: 750.947
#
# ===============================================
# ===============================================
# sample: 16200, acc. rate: 0.25, log(P): 1171.2
# SIAE: 2.498
#  SSAN: 3.310
#  PPQ: 0.520
#  TEFO: 0.021
#  PHIMIN: 12.593
#  PHIMAX: 42.652
#  ZMIN: -605.770
#  ZMAX: 605.745
#
# ===============================================
# ===============================================
# sample: 16300, acc. rate: 0.21, log(P): 1172.8
# SIAE: 2.459
#  SSAN: 3.293
#  PPQ: 0.542
#  TEFO: 0.021
#  PHIMIN: 11.919
#  PHIMAX: 43.306
#  ZMIN: -603.836
#  ZMAX: 678.472
#
# ===============================================
# ===============================================
# sample: 16400, acc. rate: 0.35, log(P): 1171.6
# SIAE: 2.237
#  SSAN: 3.230
#  PPQ: 0.526
#  TEFO: 0.024
#  PHIMIN: 12.203
#  PHIMAX: 40.844
#  ZMIN: -408.428
#  ZMAX: 587.107
#
# ===============================================
# ===============================================
# sample: 16500, acc. rate: 0.19, log(P): 1173.9
# SIAE: 2.146
#  SSAN: 3.324
#  PPQ: 0.580
#  TEFO: 0.020
#  PHIMIN: 10.629
#  PHIMAX: 41.740
#  ZMIN: -700.168
#  ZMAX: 615.445
#
# ===============================================
# ===============================================
# sample: 16600, acc. rate: 0.28, log(P): 1174.0
# SIAE: 2.340
#  SSAN: 3.365
#  PPQ: 0.489
#  TEFO: 0.024
#  PHIMIN: 10.032
#  PHIMAX: 41.459
#  ZMIN: -687.350
#  ZMAX: 688.527
#
# ===============================================
# ===============================================
# sample: 16700, acc. rate: 0.32, log(P): 1172.8
# SIAE: 2.568
#  SSAN: 3.248
#  PPQ: 0.466
#  TEFO: 0.024
#  PHIMIN: 14.748
#  PHIMAX: 41.630
#  ZMIN: -422.990
#  ZMAX: 656.778
#
# ===============================================
# ===============================================
# sample: 16800, acc. rate: 0.18, log(P): 1173.1
# SIAE: 2.665
#  SSAN: 3.339
#  PPQ: 0.398
#  TEFO: 0.026
#  PHIMIN: 14.239
#  PHIMAX: 42.848
#  ZMIN: -446.097
#  ZMAX: 810.955
#
# ===============================================
# ===============================================
# ...
#  PHIMAX: 41.793
#  ZMIN: -576.896
#  ZMAX: 664.938
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 14100, acc. rate: 0.31, log(P): 1169.6
# SIAE: 2.288
#  SSAN: 3.338
#  PPQ: 0.484
#  TEFO: 0.026
#  PHIMIN: 13.010
#  PHIMAX: 41.450
#  ZMIN: -517.109
#  ZMAX: 841.937
#
# ===============================================
# ===============================================
# sample: 14200, acc. rate: 0.24, log(P): 1173.5
# SIAE: 2.192
#  SSAN: 3.291
#  PPQ: 0.598
#  TEFO: 0.023
#  PHIMIN: 10.145
#  PHIMAX: 41.217
#  ZMIN: -614.709
#  ZMAX: 697.405
#
# ===============================================
# ===============================================
# sample: 14300, acc. rate: 0.22, log(P): 1171.2
# SIAE: 2.287
#  SSAN: 3.285
#  PPQ: 0.621
#  TEFO: 0.021
#  PHIMIN: 15.312
#  PHIMAX: 42.070
#  ZMIN: -442.204
#  ZMAX: 602.336
#
# ===============================================
# ===============================================
# sample: 14400, acc. rate: 0.25, log(P): 1169.3
# SIAE: 2.395
#  SSAN: 3.305
#  PPQ: 0.586
#  TEFO: 0.020
#  PHIMIN: 14.829
#  PHIMAX: 42.198
#  ZMIN: -556.168
#  ZMAX: 609.237
#
# ===============================================
# ===============================================
# sample: 14500, acc. rate: 0.25, log(P): 1171.2
# SIAE: 2.351
#  SSAN: 3.289
#  PPQ: 0.610
#  TEFO: 0.019
#  PHIMIN: 13.916
#  PHIMAX: 42.979
#  ZMIN: -542.454
#  ZMAX: 566.062
#
# ===============================================
# ===============================================
# sample: 14600, acc. rate: 0.28, log(P): 1169.3
# SIAE: 2.446
#  SSAN: 3.323
#  PPQ: 0.548
#  TEFO: 0.022
#  PHIMIN: 12.867
#  PHIMAX: 41.548
#  ZMIN: -575.699
#  ZMAX: 552.931
#
# ===============================================
# ===============================================
# sample: 14700, acc. rate: 0.26, log(P): 1170.8
# SIAE: 2.291
#  SSAN: 3.315
#  PPQ: 0.573
#  TEFO: 0.024
#  PHIMIN: 13.633
#  PHIMAX: 42.042
#  ZMIN: -685.502
#  ZMAX: 842.043
#
# ===============================================
# ===============================================
# sample: 14800, acc. rate: 0.26, log(P): 1175.1
# SIAE: 2.364
#  SSAN: 3.327
#  PPQ: 0.604
#  TEFO: 0.020
#  PHIMIN: 17.975
#  PHIMAX: 44.032
#  ZMIN: -254.375
#  ZMAX: 493.626
#
# ===============================================
# ===============================================
# sample: 14900, acc. rate: 0.24, log(P): 1172.4
# SIAE: 2.284
#  SSAN: 3.320
#  PPQ: 0.548
#  TEFO: 0.019
#  PHIMIN: 13.653
#  PHIMAX: 41.463
#  ZMIN: -465.325
#  ZMAX: 318.797
#
# ===============================================
# ===============================================
# sample: 15000, acc. rate: 0.31, log(P): 1170.3
# SIAE: 2.402
#  SSAN: 3.298
#  PPQ: 0.585
#  TEFO: 0.022
#  PHIMIN: 14.890
#  PHIMAX: 41.975
#  ZMIN: -374.976
#  ZMAX: 588.673
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 15100, acc. rate: 0.27, log(P): 1173.0
# SIAE: 2.687
#  SSAN: 3.395
#  PPQ: 0.370
#  TEFO: 0.023
#  PHIMIN: 15.803
#  PHIMAX: 43.060
#  ZMIN: -645.058
#  ZMAX: 652.638
#
# ===============================================
# ===============================================
# sample: 15200, acc. rate: 0.18, log(P): 1170.5
# SIAE: 2.413
#  SSAN: 3.277
#  PPQ: 0.590
#  TEFO: 0.020
#  PHIMIN: 13.520
#  PHIMAX: 42.943
#  ZMIN: -513.252
#  ZMAX: 507.717
#
# ===============================================
# ===============================================
# sample: 15300, acc. rate: 0.25, log(P): 1170.0
# SIAE: 2.285
#  SSAN: 3.288
#  PPQ: 0.618
#  TEFO: 0.021
#  PHIMIN: 13.182
#  PHIMAX: 42.002
#  ZMIN: -503.729
#  ZMAX: 571.852
#
# ===============================================
# ===============================================
# sample: 15400, acc. rate: 0.26, log(P): 1170.8
# SIAE: 2.233
#  SSAN: 3.253
#  PPQ: 0.551
#  TEFO: 0.022
#  PHIMIN: 9.791
#  PHIMAX: 41.900
#  ZMIN: -461.877
#  ZMAX: 571.154
#
# ===============================================
# ===============================================
# sample: 15500, acc. rate: 0.26, log(P): 1170.5
# SIAE: 2.310
#  SSAN: 3.302
#  PPQ: 0.572
#  TEFO: 0.022
#  PHIMIN: 12.554
#  PHIMAX: 41.983
#  ZMIN: -732.237
#  ZMAX: 724.498
#
# ===============================================
# ===============================================
# sample: 15600, acc. rate: 0.27, log(P): 1174.6
# SIAE: 2.084
#  SSAN: 3.256
#  PPQ: 0.646
#  TEFO: 0.023
#  PHIMIN: 14.143
#  PHIMAX: 41.695
#  ZMIN: -624.167
#  ZMAX: 891.022
#
# ===============================================
# ===============================================
# sample: 15700, acc. rate: 0.26, log(P): 1174.0
# SIAE: 2.263
#  SSAN: 3.211
#  PPQ: 0.590
#  TEFO: 0.020
#  PHIMIN: 10.493
#  PHIMAX: 42.299
#  ZMIN: -581.735
#  ZMAX: 508.421
#
# ===============================================
# ===============================================
# sample: 15800, acc. rate: 0.23, log(P): 1174.0
# SIAE: 2.193
#  SSAN: 3.297
#  PPQ: 0.591
#  TEFO: 0.025
#  PHIMIN: 10.572
#  PHIMAX: 42.967
#  ZMIN: -550.716
#  ZMAX: 787.092
#
# ===============================================
# ===============================================
# sample: 15900, acc. rate: 0.16, log(P): 1172.7
# SIAE: 2.215
#  SSAN: 3.295
#  PPQ: 0.589
#  TEFO: 0.018
#  PHIMIN: 11.011
#  PHIMAX: 43.465
#  ZMIN: -650.891
#  ZMAX: 523.786
#
# ===============================================
# ===============================================
# sample: 16000, acc. rate: 0.28, log(P): 1172.8
# SIAE: 2.351
#  SSAN: 3.265
#  PPQ: 0.592
#  TEFO: 0.019
#  PHIMIN: 12.883
#  PHIMAX: 42.808
#  ZMIN: -524.151
#  ZMAX: 527.169
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 16100, acc. rate: 0.30, log(P): 1171.9
# SIAE: 2.288
#  SSAN: 3.294
#  PPQ: 0.494
#  TEFO: 0.024
#  PHIMIN: 10.544
#  PHIMAX: 40.417
#  ZMIN: -624.350
#  ZMAX: 607.439
#
# ===============================================
# ===============================================
# sample: 16200, acc. rate: 0.23, log(P): 1177.0
# SIAE: 2.005
#  SSAN: 3.152
#  PPQ: 0.619
#  TEFO: 0.020
#  PHIMIN: 15.752
#  PHIMAX: 42.079
#  ZMIN: -787.420
#  ZMAX: 865.232
#
# ===============================================
# ===============================================
# sample: 16300, acc. rate: 0.26, log(P): 1174.5
# SIAE: 2.346
#  SSAN: 3.250
#  PPQ: 0.584
#  TEFO: 0.019
#  PHIMIN: 11.842
#  PHIMAX: 43.358
#  ZMIN: -549.653
#  ZMAX: 499.309
#
# ===============================================
# ===============================================
# sample: 16400, acc. rate: 0.26, log(P): 1168.2
# SIAE: 2.384
#  SSAN: 3.287
#  PPQ: 0.553
#  TEFO: 0.021
#  PHIMIN: 13.145
#  PHIMAX: 42.808
#  ZMIN: -486.752
#  ZMAX: 593.531
#
# ===============================================
# ===============================================
# sample: 16500, acc. rate: 0.28, log(P): 1169.6
# SIAE: 2.230
#  SSAN: 3.266
#  PPQ: 0.608
#  TEFO: 0.019
#  PHIMIN: 14.252
#  PHIMAX: 42.504
#  ZMIN: -456.424
#  ZMAX: 484.668
#
# ===============================================
# ===============================================
# sample: 16600, acc. rate: 0.24, log(P): 1170.9
# SIAE: 2.381
#  SSAN: 3.257
#  PPQ: 0.580
#  TEFO: 0.021
#  PHIMIN: 14.321
#  PHIMAX: 42.811
#  ZMIN: -525.214
#  ZMAX: 673.250
#
# ===============================================
# ===============================================
# sample: 16700, acc. rate: 0.21, log(P): 1174.4
# SIAE: 2.260
#  SSAN: 3.221
#  PPQ: 0.600
#  TEFO: 0.020
#  PHIMIN: 17.638
#  PHIMAX: 44.448
#  ZMIN: -244.822
#  ZMAX: 433.171
#
# ===============================================
# ===============================================
# sample: 16800, acc. rate: 0.25, log(P): 1172.8
# SIAE: 2.394
#  SSAN: 3.303
#  PPQ: 0.564
#  TEFO: 0.019
#  PHIMIN: 13.322
#  PHIMAX: 43.615
#  ZMIN: -521.639
#  ZMAX: 482.159
#
# ===============================================
# ===============================================
# sample: 16900, acc. rate: 0.24, log(P): 1173.0
# SIAE: 2.411
#  SSAN: 3.235
#  PPQ: 0.565
#  TEFO: 0.020
#  PHIMIN: 16.601
#  PHIMAX: 43.511
#  ZMIN: -342.877
#  ZMAX: 396.892
#
# ===============================================
# ===============================================
# sample: 17000, acc. rate: 0.18, log(P): 1173.6
# SIAE: 2.241
#  SSAN: 3.285
#  PPQ: 0.608
#  TEFO: 0.021
#  PHIMIN: 12.403
#  PHIMAX: 44.106
#  ZMIN: -471.913
#  ZMAX: 593.996
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 17100, acc. rate: 0.27, log(P): 1172.7
# SIAE: 2.191
#  SSAN: 3.283
#  PPQ: 0.604
#  TEFO: 0.018
#  PHIMIN: 11.160
#  PHIMAX: 43.214
#  ZMIN: -489.256
#  ZMAX: 419.293
#
# ===============================================
# ===============================================
# sample: 17200, acc. rate: 0.28, log(P): 1170.0
# SIAE: 2.318
#  SSAN: 3.306
#  PPQ: 0.559
#  TEFO: 0.021
#  PHIMIN: 15.682
#  PHIMAX: 41.255
#  ZMIN: -414.260
#  ZMAX: 523.684
#
# ===============================================
# ===============================================
# sample: 17300, acc. rate: 0.24, log(P): 1169.0
# SIAE: 2.347
#  SSAN: 3.289
#  PPQ: 0.597
#  TEFO: 0.022
#  PHIMIN: 13.920
#  PHIMAX: 42.110
#  ZMIN: -447.189
#  ZMAX: 642.468
#
# ===============================================
# ===============================================
# sample: 17400, acc. rate: 0.24, log(P): 1170.8
# SIAE: 2.515
#  SSAN: 3.334
#  PPQ: 0.576
#  TEFO: 0.022
#  PHIMIN: 14.067
#  PHIMAX: 42.586
#  ZMIN: -532.358
#  ZMAX: 656.048
#
# ===============================================
# ===============================================
# sample: 17500, acc. rate: 0.27, log(P): 1171.7
# SIAE: 2.272
#  SSAN: 3.284
#  PPQ: 0.612
#  TEFO: 0.021
#  PHIMIN: 10.960
#  PHIMAX: 42.085
#  ZMIN: -559.775
#  ZMAX: 582.788
#
# ===============================================
# ===============================================
# sample: 17600, acc. rate: 0.24, log(P): 1169.7
# SIAE: 2.275
#  SSAN: 3.282
#  PPQ: 0.550
#  TEFO: 0.020
#  PHIMIN: 13.584
#  PHIMAX: 41.740
#  ZMIN: -598.924
#  ZMAX: 575.206
#
# ===============================================
# ===============================================
# sample: 17700, acc. rate: 0.20, log(P): 1169.0
# SIAE: 2.466
#  SSAN: 3.311
#  PPQ: 0.523
#  TEFO: 0.022
#  PHIMIN: 15.568
#  PHIMAX: 42.340
#  ZMIN: -597.467
#  ZMAX: 716.217
#
# ===============================================
# ===============================================
# sample: 17800, acc. rate: 0.32, log(P): 1172.2
# SIAE: 2.429
#  SSAN: 3.311
#  PPQ: 0.582
#  TEFO: 0.023
#  PHIMIN: 11.977
#  PHIMAX: 41.490
#  ZMIN: -585.342
#  ZMAX: 638.898
#
# ===============================================
# ===============================================
# sample: 17900, acc. rate: 0.24, log(P): 1169.8
# SIAE: 2.325
#  SSAN: 3.264
#  PPQ: 0.585
#  TEFO: 0.021
#  PHIMIN: 11.788
#  PHIMAX: 41.967
#  ZMIN: -574.788
#  ZMAX: 525.792
#
# ===============================================
# ===============================================
# sample: 18000, acc. rate: 0.29, log(P): 1169.7
# SIAE: 2.468
#  SSAN: 3.326
#  PPQ: 0.539
#  TEFO: 0.022
#  PHIMIN: 13.671
#  PHIMAX: 41.690
#  ZMIN: -480.964
#  ZMAX: 637.595
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 18100, acc. rate: 0.17, log(P): 1172.1
# SIAE: 2.157
#  SSAN: 3.234
#  PPQ: 0.531
#  TEFO: 0.021
#  PHIMIN: 9.421
#  PHIMAX: 41.824
#  ZMIN: -451.081
#  ZMAX: 547.283
#
# ===============================================
# ===============================================
# sample: 18200, acc. rate: 0.30, log(P): 1172.3
# SIAE: 2.250
#  SSAN: 3.311
#  PPQ: 0.603
#  TEFO: 0.020
#  PHIMIN: 12.968
#  PHIMAX: 42.160
#  ZMIN: -471.927
#  ZMAX: 545.346
#
# ===============================================
# ===============================================
# sample: 18300, acc. rate: 0.28, log(P): 1171.7
# SIAE: 1.960
#  SSAN: 3.266
#  PPQ: 0.496
#  TEFO: 0.022
#  PHIMIN: 10.983
#  PHIMAX: 40.597
#  ZMIN: -543.678
#  ZMAX: 632.083
#
# ===============================================
# ===============================================
# sample: 18400, acc. rate: 0.19, log(P): 1168.4
# SIAE: 2.427
#  SSAN: 3.287
#  PPQ: 0.549
#  TEFO: 0.021
#  PHIMIN: 15.082
#  PHIMAX: 41.857
#  ZMIN: -492.273
#  ZMAX: 588.634
#
# ===============================================
# ===============================================
# sample: 18500, acc. rate: 0.28, log(P): 1173.5
# SIAE: 2.322
#  SSAN: 3.264
#  PPQ: 0.608
#  TEFO: 0.020
#  PHIMIN: 13.217
#  PHIMAX: 42.114
#  ZMIN: -521.897
#  ZMAX: 597.479
#
# ===============================================
# ===============================================
# sample: 18600, acc. rate: 0.27, log(P): 1174.3
# SIAE: 2.585
#  SSAN: 3.341
#  PPQ: 0.395
#  TEFO: 0.026
#  PHIMIN: 13.915
#  PHIMAX: 42.067
#  ZMIN: -626.147
#  ZMAX: 899.552
#
# ===============================================
# ===============================================
# sample: 18700, acc. rate: 0.22, log(P): 1172.4
# SIAE: 2.628
#  SSAN: 3.363
#  PPQ: 0.505
#  TEFO: 0.024
#  PHIMIN: 17.773
#  PHIMAX: 43.024
#  ZMIN: -466.246
#  ZMAX: 728.970
#
# ===============================================
# ===============================================
# sample: 18800, acc. rate: 0.27, log(P): 1172.9
# SIAE: 2.473
#  SSAN: 3.369
#  PPQ: 0.552
#  TEFO: 0.025
#  PHIMIN: 16.725
#  PHIMAX: 41.128
#  ZMIN: -461.166
#  ZMAX: 788.809
#
# ===============================================
# ===============================================
# sample: 18900, acc. rate: 0.19, log(P): 1174.4
# SIAE: 2.341
#  SSAN: 3.162
#  PPQ: 0.568
#  TEFO: 0.022
#  PHIMIN: 17.076
#  PHIMAX: 42.885
#  ZMIN: -274.070
#  ZMAX: 548.135
#
# ===============================================
# ===============================================
# sample: 19000, acc. rate: 0.28, log(P): 1170.8
# SIAE: 2.328
#  SSAN: 3.290
#  PPQ: 0.564
#  TEFO: 0.020
#  PHIMIN: 13.802
#  PHIMAX: 43.813
#  ZMIN: -526.879
#  ZMAX: 596.188
#
# ===============================================
# ///////////////////////////////////////////////
# Saving samples for model 3
# ///////////////////////////////////////////////
# ===============================================
# sample: 19100, acc. rate: 0.31, log(P): 1175.5
# SIAE: 2.361
#  SSAN: 3.245
#  PPQ: 0.566
#  TEFO: 0.018
#  PHIMIN: 13.646
#  PHIMAX: 43.045
#  ZMIN: -570.567
#  ZMAX: 420.126
#
# ===============================================
# ===============================================
# sample: 19200, acc. rate: 0.20, log(P): 1171.1
# SIAE: 2.338
#  SSAN: 3.315
#  PPQ: 0.553
#  TEFO: 0.024
#  PHIMIN: 10.533
#  PHIMAX: 42.338
#  ZMIN: -678.545
#  ZMAX: 787.145
#
# ===============================================
# ===============================================
# sample: 19300, acc. rate: 0.30, log(P): 1169.2
# SIAE: 2.348
#  SSAN: 3.328
#  PPQ: 0.580
#  TEFO: 0.020
#  PHIMIN: 14.361
#  PHIMAX: 42.245
#  ZMIN: -448.091
#  ZMAX: 549.934
#
# ===============================================
# ===============================================
# sample: 19400, acc. rate: 0.25, log(P): 1173.5
# SIAE: 2.391
#  SSAN: 3.314
#  PPQ: 0.548
#  TEFO: 0.020
#  PHIMIN: 15.095
#  PHIMAX: 43.758
#  ZMIN: -356.408
#  ZMAX: 521.794
#
# ===============================================
# ===============================================
# sample: 19500, acc. rate: 0.27, log(P): 1170.6
# SIAE: 2.373
#  SSAN: 3.255
#  PPQ: 0.579
#  TEFO: 0.021
#  PHIMIN: 11.267
#  PHIMAX: 42.353
#  ZMIN: -534.561
#  ZMAX: 573.076
#
# ===============================================
# ===============================================
# sample: 19600, acc. rate: 0.24, log(P): 1171.1
# SIAE: 2.559
#  SSAN: 3.314
#  PPQ: 0.567
#  TEFO: 0.022
#  PHIMIN: 15.014
#  PHIMAX: 42.481
#  ZMIN: -593.512
#  ZMAX: 665.711
#
# ===============================================
# ===============================================
# sample: 19700, acc. rate: 0.24, log(P): 1171.3
# SIAE: 2.356
#  SSAN: 3.200
#  PPQ: 0.527
#  TEFO: 0.021
#  PHIMIN: 15.293
#  PHIMAX: 43.119
#  ZMIN: -402.835
#  ZMAX: 549.113
#
# ===============================================
# ===============================================
# sample: 19800, acc. rate: 0.32, log(P): 1174.9
# SIAE: 2.052
#  SSAN: 3.332
#  PPQ: 0.651
#  TEFO: 0.019
#  PHIMIN: 15.681
#  PHIMAX: 43.763
#  ZMIN: -382.570
#  ZMAX: 484.270
#
# ===============================================
# ===============================================
# sample: 19900, acc. rate: 0.22, log(P): 1174.3
# SIAE: 2.555
#  SSAN: 3.265
#  PPQ: 0.583
#  TEFO: 0.023
#  PHIMIN: 14.770
#  PHIMAX: 42.176
#  ZMIN: -465.375
#  ZMAX: 629.121
#
# ===============================================
